# %%
import ioNERDSS as io

# %%
result = io.multi_hist(FileName = 'histogram_complexes_time.dat', FileNum = 1, InitialTime = 10.622, \
                      FinalTime = 18.712, SpeciesList = ['IL', 'gag', 'pol'], xAxis = 'tot', BarSize = 50,\
                      ExcludeSize = 1000)

# %%
result = io.multi_hist(FileName = 'histogram_complexes_time.dat', FileNum = 1, InitialTime = 8.622, \
                      FinalTime = 18.712, SpeciesList = ['IL', 'gag', 'pol'], xAxis = 'gag', BarSize = 30,\
                      ExcludeSize = 1000)

# %%
result = io.multi_hist(FileName = 'histogram_complexes_time.dat', FileNum = 1, InitialTime = 8.622, \
                      FinalTime = 18.712, SpeciesList = ['IL', 'gag', 'pol'], xAxis = 'pol', \
                      BarSize = 2, ExcludeSize = 50)

# %%
result = io.multi_hist(FileName = 'histogram_complexes_time.dat', FileNum = 1, InitialTime = 8.622, \
                      FinalTime = 18.712, SpeciesList = ['IL', 'gag', 'pol'], xAxis = 'pol', \
                      BarSize = 2)

# %%
result = io.multi_hist(FileName = 'histogram_complexes_time.dat', FileNum = 1, InitialTime = 8.622, \
                      FinalTime = 18.712, SpeciesList = ['IL', 'gag', 'pol'], xAxis = 'IL', BarSize = 50,\
                      ExcludeSize = 1000)

# %%
result = io.multi_hist_stacked(FileName = 'histogram_complexes_time.dat', FileNum = 1, InitialTime = 8.622, \
                              FinalTime = 18.712, SpeciesList = ['IL', 'gag', 'pol'], xAxis = 'gag', \
                              DivideSpecies = 'pol', DivideSize = 116, BarSize = 30, ExcludeSize = 1000)
