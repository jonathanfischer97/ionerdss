# %%
import sys
import os

# Go two levels up from docs/source/ to reach the project root
# sys.path.insert(0, os.path.abspath('../../'))

import ionerdss as ion
import subprocess
from IPython.display import display, Image

# %% [markdown]
# Homo 180mer

# %%
pdb_id = '5lqp'
save_folder = '~/Documents/5lqp_dir'

pdb_model = ion.PDBModel(pdb_id=pdb_id, save_dir=save_folder)

# set standard_output=True to see the determined interfaces
pdb_model.coarse_grain(distance_cutoff=0.35, 
                       residue_cutoff=3,
                       show_coarse_grained_structure=False, 
                       save_pymol_script=False, 
                       standard_output=True)
# Out:
# Successfully downloaded assembly file: /Users/sikao/Documents/5lqp_dir/5lqp-assembly1.cif.gz
# Binding interfaces detected:
# Chain AB:
#   Center of Mass (COM): (246.0711212158203, 393.1337585449219, 231.68157958984375)
#   Interfaces: ['AC', 'AD', 'DI', 'DP']
#   Interface Coordinates:
#     (265.3112487792969, 386.1487731933594, 220.39401245117188)
#     Interface Energy: -8.03
#     (246.14024353027344, 392.3477783203125, 247.39950561523438)
#     Interface Energy: -8.80
#     (244.14588928222656, 394.69970703125, 227.9365692138672)
#     Interface Energy: -187.63
#     (248.9609832763672, 397.96038818359375, 248.785400390625)
#     Interface Energy: -34.00
# Chain AC:
#   Center of Mass (COM): (287.8408508300781, 392.9450988769531, 226.6455535888672)
#   Interfaces: ['AB', 'AD', 'FG']
#   Interface Coordinates:
#     (272.753662109375, 391.731689453125, 223.1959991455078)
#     Interface Energy: -8.03
#     (285.2776184082031, 389.7743835449219, 246.472412109375)
#     Interface Energy: -20.90
#     (291.84027099609375, 393.8691711425781, 226.69790649414062)
#     Interface Energy: -187.63
# Chain AD:
#   Center of Mass (COM): (271.1116027832031, 396.9188537597656, 264.00738525390625)
#   Interfaces: ['AB', 'AC', 'DN', 'DP']
#   Interface Coordinates:
#     (249.97132873535156, 391.5906677246094, 256.1666564941406)
#     Interface Energy: -8.80
#     (279.54718017578125, 392.8004150390625, 251.16940307617188)
#     Interface Energy: -20.90
#     (290.1670227050781, 399.2758483886719, 277.3089904785156)
#     Interface Energy: -34.00
#     (267.709716796875, 398.10833740234375, 265.7810363769531)
#     Interface Energy: -225.98
# Chain AE:
#   Center of Mass (COM): (271.4385681152344, 183.91168212890625, 165.26942443847656)
#   Interfaces: ['AF', 'AG', 'DL', 'DS']
#   Interface Coordinates:
#     (279.2015075683594, 172.32675170898438, 184.02825927734375)
#     Interface Energy: -8.03
#     (279.1105041503906, 196.99923706054688, 161.08224487304688)
#     Interface Energy: -8.80
#     (268.49224853515625, 180.69354248046875, 164.1969451904297)
#     Interface Energy: -187.63
#     (283.819580078125, 194.44239807128906, 157.5240020751953)
#     Interface Energy: -34.00
# Chain AF:
#   Center of Mass (COM): (302.6544189453125, 167.02398681640625, 187.8631591796875)
#   Interfaces: ['AE', 'AG', 'FJ']
#   Interface Coordinates:
#     (288.3489990234375, 169.50233459472656, 182.36700439453125)
#     Interface Energy: -8.03
#     (309.51422119140625, 185.44139099121094, 183.0196075439453)
#     Interface Energy: -20.90
#     (306.20172119140625, 165.3683319091797, 189.09884643554688)
#     Interface Energy: -187.63
# Chain AG:
#   Center of Mass (COM): (309.0291442871094, 200.433349609375, 164.738037109375)
#   Interfaces: ['AE', 'AF', 'DQ', 'DS']
#   Interface Coordinates:
#     (286.3593444824219, 203.2863311767578, 160.90133666992188)
#     Interface Energy: -8.80
#     (308.1620178222656, 189.4993896484375, 176.2548065185547)
#     Interface Energy: -20.90
#     (331.8244934082031, 204.12750244140625, 168.2483367919922)
#     Interface Energy: -34.00
#     (307.5313720703125, 202.324462890625, 161.526611328125)
#     Interface Energy: -225.98
# Chain AH:
#   Center of Mass (COM): (194.10177612304688, 226.95472717285156, 367.739501953125)
#   Interfaces: ['AI', 'AJ', 'DF', 'DV']
#   Interface Coordinates:
#     (206.1817626953125, 245.5244903564453, 375.1969909667969)
#     Interface Energy: -8.03
#     (202.25900268554688, 214.6529998779297, 362.28125)
#     Interface Energy: -8.80
#     (190.18743896484375, 228.60671997070312, 369.2013854980469)
#     Interface Energy: -187.63
#     (203.49960327148438, 211.5972137451172, 367.80419921875)
#     Interface Energy: -34.00
# Chain AI:
#   Center of Mass (COM): (225.43421936035156, 244.0312042236328, 390.0279846191406)
#   Interfaces: ['AH', 'AJ', 'FM']
#   Interface Coordinates:
#     (211.878662109375, 242.7659912109375, 382.5686950683594)
#     Interface Energy: -8.03
#     (234.2535858154297, 228.7841796875, 380.0545959472656)
#     Interface Energy: -20.90
#     (228.41049194335938, 244.7625274658203, 392.7593688964844)
#     Interface Energy: -187.63
# Chain AJ:
#   Center of Mass (COM): (229.35301208496094, 206.6483917236328, 373.33258056640625)
#   Interfaces: ['AH', 'AI', 'DT', 'DV']
#   Interface Coordinates:
#     (209.97633361816406, 209.1230010986328, 360.8753356933594)
#     Interface Energy: -8.80
#     (231.031005859375, 221.7001953125, 378.18597412109375)
#     Interface Energy: -20.90
#     (250.69151306152344, 200.5966796875, 380.6571350097656)
#     Interface Energy: -34.00
#     (227.12005615234375, 203.567138671875, 372.04632568359375)
#     Interface Energy: -225.98
# Chain AK:
#   Center of Mass (COM): (246.0711212158203, 142.86654663085938, 301.6383972167969)
#   Interfaces: ['AL', 'AM', 'CT', 'DY']
#   Interface Coordinates:
#     (265.3112487792969, 149.85125732421875, 312.9259948730469)
#     Interface Energy: -8.03
#     (246.14024353027344, 143.65225219726562, 285.9205322265625)
#     Interface Energy: -8.80
#     (244.14588928222656, 141.30027770996094, 305.38348388671875)
#     Interface Energy: -187.63
#     (248.9609832763672, 138.03958129882812, 284.53460693359375)
#     Interface Energy: -34.00
# Chain AL:
#   Center of Mass (COM): (287.8408508300781, 143.05526733398438, 306.67462158203125)
#   Interfaces: ['AK', 'AM', 'EX']
#   Interface Coordinates:
#     (272.753662109375, 144.26834106445312, 310.1239929199219)
#     Interface Energy: -8.03
#     (285.2776184082031, 146.22560119628906, 286.84759521484375)
#     Interface Energy: -20.90
#     (291.84027099609375, 142.13087463378906, 306.6220703125)
#     Interface Energy: -187.63
# Chain AM:
#   Center of Mass (COM): (271.1116027832031, 139.08131408691406, 269.31268310546875)
#   Interfaces: ['AK', 'AL', 'DW', 'DY']
#   Interface Coordinates:
#     (249.97132873535156, 144.40933227539062, 277.1533203125)
#     Interface Energy: -8.80
#     (279.54718017578125, 143.19961547851562, 282.15057373046875)
#     Interface Energy: -20.90
#     (290.1670227050781, 136.7241668701172, 256.0110168457031)
#     Interface Energy: -34.00
#     (267.709716796875, 137.89163208007812, 267.53887939453125)
#     Interface Energy: -225.98
# Chain AN:
#   Center of Mass (COM): (229.08013916015625, 365.64129638671875, 346.1219482421875)
#   Interfaces: ['AO', 'AP', 'CN', 'EB']
#   Interface Coordinates:
#     (252.44775390625, 365.33526611328125, 346.6029968261719)
#     Interface Energy: -8.03
#     (221.51950073242188, 352.510986328125, 350.37799072265625)
#     Interface Energy: -8.80
#     (228.9109344482422, 370.0491943359375, 345.2689208984375)
#     Interface Energy: -187.63
#     (221.3741912841797, 353.32440185546875, 356.75701904296875)
#     Interface Energy: -34.00
# Chain AO:
#   Center of Mass (COM): (265.4488830566406, 356.71368408203125, 365.2978210449219)
#   Interfaces: ['AN', 'AP', 'FA']
#   Interface Coordinates:
#     (255.34266662597656, 363.5599670410156, 355.7066650390625)
#     Interface Energy: -8.03
#     (254.4412078857422, 339.88037109375, 367.5779724121094)
#     Interface Energy: -20.90
#     (268.3725891113281, 355.89752197265625, 368.0614318847656)
#     Interface Energy: -187.63
# Chain AP:
#   Center of Mass (COM): (232.00552368164062, 333.6437683105469, 371.69329833984375)
#   Interfaces: ['AN', 'AO', 'DZ', 'EB']
#   Interface Coordinates:
#     (220.46966552734375, 343.8556823730469, 354.3900146484375)
#     Interface Energy: -8.80
#     (246.5216064453125, 339.36419677734375, 368.6123962402344)
#     Interface Energy: -20.90
#     (240.04249572753906, 318.1728210449219, 387.2386779785156)
#     Interface Energy: -34.00
#     (227.9989471435547, 333.85498046875, 371.50311279296875)
#     Interface Energy: -225.98
# Chain AQ:
#   Center of Mass (COM): (306.4167175292969, 295.49249267578125, 143.6515655517578)
#   Interfaces: ['AR', 'AS', 'CQ', 'EE']
#   Interface Coordinates:
#     (325.4674987792969, 288.8135070800781, 155.4342498779297)
#     Interface Energy: -8.03
#     (298.3710021972656, 307.8367614746094, 149.1790008544922)
#     Interface Energy: -8.80
#     (307.21563720703125, 292.6505432128906, 140.26451110839844)
#     Interface Energy: -187.63
#     (301.6942138671875, 312.635986328125, 146.47679138183594)
#     Interface Energy: -34.00
# Chain AR:
#   Center of Mass (COM): (342.66888427734375, 304.2313537597656, 163.13278198242188)
#   Interfaces: ['AQ', 'AS', 'FD']
#   Interface Coordinates:
#     (331.81298828125, 296.1716613769531, 155.5050048828125)
#     Interface Energy: -8.03
#     (329.7018127441406, 317.89398193359375, 170.54299926757812)
#     Interface Energy: -20.90
#     (346.16387939453125, 305.9715881347656, 164.40090942382812)
#     Interface Energy: -187.63
# Chain AS:
#   Center of Mass (COM): (311.6814270019531, 331.2748718261719, 163.09864807128906)
#   Interfaces: ['AQ', 'AR', 'EC', 'EE']
#   Interface Coordinates:
#     (296.8526611328125, 315.7350158691406, 154.41600036621094)
#     Interface Energy: -8.80
#     (323.6526184082031, 321.43621826171875, 166.6811981201172)
#     Interface Energy: -20.90
#     (321.17547607421875, 349.1029968261719, 174.829833984375)
#     Interface Energy: -34.00
#     (308.4103088378906, 332.2533874511719, 160.98341369628906)
#     Interface Energy: -225.98
# Chain AT:
#   Center of Mass (COM): (369.0795593261719, 341.8984680175781, 307.7051086425781)
#   Interfaces: ['AU', 'AV', 'BJ', 'EH']
#   Interface Coordinates:
#     (376.5369873046875, 329.8182373046875, 289.135498046875)
#     Interface Energy: -8.03
#     (363.62127685546875, 333.7409973144531, 320.00701904296875)
#     Interface Energy: -8.80
#     (370.5413513183594, 345.8125915527344, 306.05328369140625)
#     Interface Energy: -187.63
#     (369.1441955566406, 332.5003967285156, 323.06280517578125)
#     Interface Energy: -34.00
# Chain AU:
#   Center of Mass (COM): (391.3680725097656, 310.565673828125, 290.62896728515625)
#   Interfaces: ['AT', 'AV', 'EI']
#   Interface Coordinates:
#     (383.90869140625, 324.121337890625, 291.8940124511719)
#     Interface Energy: -8.03
#     (381.39459228515625, 301.74639892578125, 305.87579345703125)
#     Interface Energy: -20.90
#     (394.0993347167969, 307.5894775390625, 289.8974304199219)
#     Interface Energy: -187.63
# Chain AV:
#   Center of Mass (COM): (374.6727294921875, 306.6469421386719, 328.0117492675781)
#   Interfaces: ['AT', 'AU', 'EF', 'EH']
#   Interface Coordinates:
#     (362.21533203125, 326.023681640625, 325.5370178222656)
#     Interface Energy: -8.80
#     (379.5260009765625, 304.968994140625, 312.9598083496094)
#     Interface Energy: -20.90
#     (381.9971618652344, 285.3085021972656, 334.0633239746094)
#     Interface Energy: -34.00
#     (373.3863220214844, 308.8799133300781, 331.0928039550781)
#     Interface Energy: -225.98
# Chain AW:
#   Center of Mass (COM): (393.1337585449219, 233.02186584472656, 244.73123168945312)
#   Interfaces: ['AX', 'AY', 'BD', 'EK']
#   Interface Coordinates:
#     (386.1487731933594, 221.73399353027344, 263.97125244140625)
#     Interface Energy: -8.03
#     (392.3477783203125, 248.739501953125, 244.80023193359375)
#     Interface Energy: -8.80
#     (394.69970703125, 229.27651977539062, 242.805908203125)
#     Interface Energy: -187.63
#     (397.96038818359375, 250.12539672851562, 247.62100219726562)
#     Interface Energy: -34.00
# Chain AX:
#   Center of Mass (COM): (392.9450988769531, 227.9853973388672, 286.5009460449219)
#   Interfaces: ['AW', 'AY', 'EL']
#   Interface Coordinates:
#     (391.731689453125, 224.53599548339844, 271.4136657714844)
#     Interface Energy: -8.03
#     (389.7743835449219, 247.81240844726562, 283.93756103515625)
#     Interface Energy: -20.90
#     (393.8691711425781, 228.0378875732422, 290.50030517578125)
#     Interface Energy: -187.63
# Chain AY:
#   Center of Mass (COM): (396.9188537597656, 265.34735107421875, 269.77142333984375)
#   Interfaces: ['AW', 'AX', 'EI', 'EK']
#   Interface Coordinates:
#     (391.5906677246094, 257.5066833496094, 248.63133239746094)
#     Interface Energy: -8.80
#     (392.8004150390625, 252.50936889648438, 278.20721435546875)
#     Interface Energy: -20.90
#     (399.2758483886719, 278.6490173339844, 288.8269958496094)
#     Interface Energy: -34.00
#     (398.10833740234375, 267.1210632324219, 266.36968994140625)
#     Interface Energy: -225.98
# Chain AZ:
#   Center of Mass (COM): (347.46209716796875, 229.08013916015625, 364.3011474609375)
#   Interfaces: ['BA', 'BB', 'BG', 'EN']
#   Interface Coordinates:
#     (347.9429931640625, 252.44775390625, 363.9952392578125)
#     Interface Energy: -8.03
#     (351.718017578125, 221.51950073242188, 351.1709899902344)
#     Interface Energy: -8.80
#     (346.60888671875, 228.9109344482422, 368.70916748046875)
#     Interface Energy: -187.63
#     (358.0970153808594, 221.3741912841797, 351.9844055175781)
#     Interface Energy: -34.00
# Chain BA:
#   Center of Mass (COM): (366.6374816894531, 265.4488830566406, 355.3736267089844)
#   Interfaces: ['AZ', 'BB', 'EF']
#   Interface Coordinates:
#     (357.046630859375, 255.34266662597656, 362.2200012207031)
#     Interface Energy: -8.03
#     (368.9179992675781, 254.4412078857422, 338.5404052734375)
#     Interface Energy: -20.90
#     (369.40142822265625, 268.3725891113281, 354.5574951171875)
#     Interface Energy: -187.63
# Chain BB:
#   Center of Mass (COM): (373.0332336425781, 232.00552368164062, 332.303955078125)
#   Interfaces: ['AZ', 'BA', 'EL', 'EN']
#   Interface Coordinates:
#     (355.72998046875, 220.46966552734375, 342.5156555175781)
#     Interface Energy: -8.80
#     (369.9524230957031, 246.5216064453125, 338.024169921875)
#     Interface Energy: -20.90
#     (388.5786437988281, 240.04249572753906, 316.8328552246094)
#     Interface Energy: -34.00
#     (372.84307861328125, 227.9989471435547, 332.51495361328125)
#     Interface Energy: -225.98
# Chain BC:
#   Center of Mass (COM): (369.0795593261719, 194.10177612304688, 225.6148681640625)
#   Interfaces: ['BD', 'BE', 'BY', 'EQ']
#   Interface Coordinates:
#     (376.5369873046875, 206.1817626953125, 244.18450927734375)
#     Interface Energy: -8.03
#     (363.62127685546875, 202.25900268554688, 213.31298828125)
#     Interface Energy: -8.80
#     (370.5413513183594, 190.18743896484375, 227.26675415039062)
#     Interface Energy: -187.63
#     (369.1441955566406, 203.49960327148438, 210.2572021484375)
#     Interface Energy: -34.00
# Chain BD:
#   Center of Mass (COM): (391.3680725097656, 225.43421936035156, 242.69131469726562)
#   Interfaces: ['AW', 'BC', 'BE']
#   Interface Coordinates:
#     (394.0993347167969, 228.41049194335938, 243.4225311279297)
#     Interface Energy: -187.63
#     (383.90869140625, 211.878662109375, 241.42601013183594)
#     Interface Energy: -8.03
#     (381.39459228515625, 234.2535858154297, 227.4442138671875)
#     Interface Energy: -20.90
# Chain BE:
#   Center of Mass (COM): (374.6727294921875, 229.35301208496094, 205.30810546875)
#   Interfaces: ['BC', 'BD', 'EO', 'EQ']
#   Interface Coordinates:
#     (362.21533203125, 209.97633361816406, 207.7830047607422)
#     Interface Energy: -8.80
#     (379.5260009765625, 231.031005859375, 220.3601837158203)
#     Interface Energy: -20.90
#     (381.9971618652344, 250.69151306152344, 199.2566680908203)
#     Interface Energy: -34.00
#     (373.3863220214844, 227.12005615234375, 202.22715759277344)
#     Interface Energy: -225.98
# Chain BF:
#   Center of Mass (COM): (306.4167175292969, 240.50759887695312, 389.668701171875)
#   Interfaces: ['BG', 'BH', 'CB', 'ET']
#   Interface Coordinates:
#     (325.4674987792969, 247.18649291992188, 377.8857421875)
#     Interface Energy: -8.03
#     (298.3710021972656, 228.1632537841797, 384.1409912109375)
#     Interface Energy: -8.80
#     (307.21563720703125, 243.34945678710938, 393.0554504394531)
#     Interface Energy: -187.63
#     (301.6942138671875, 223.364013671875, 386.84320068359375)
#     Interface Energy: -34.00
# Chain BG:
#   Center of Mass (COM): (342.66888427734375, 231.76876831054688, 370.1869812011719)
#   Interfaces: ['AZ', 'BF', 'BH']
#   Interface Coordinates:
#     (346.16387939453125, 230.0283660888672, 368.91912841796875)
#     Interface Energy: -187.63
#     (331.81298828125, 239.8283233642578, 377.8150329589844)
#     Interface Energy: -8.03
#     (329.7018127441406, 218.1060028076172, 362.7770080566406)
#     Interface Energy: -20.90
# Chain BH:
#   Center of Mass (COM): (311.6814270019531, 204.72500610351562, 370.2214050292969)
#   Interfaces: ['BF', 'BG', 'ER', 'ET']
#   Interface Coordinates:
#     (296.8526611328125, 220.2650146484375, 378.9039611816406)
#     Interface Energy: -8.80
#     (323.6526184082031, 214.5637969970703, 366.6388244628906)
#     Interface Energy: -20.90
#     (321.17547607421875, 186.89698791503906, 358.4901428222656)
#     Interface Energy: -34.00
#     (308.4103088378906, 203.74655151367188, 372.3365478515625)
#     Interface Energy: -225.98
# Chain BI:
#   Center of Mass (COM): (352.0885009765625, 369.3907165527344, 270.09857177734375)
#   Interfaces: ['BJ', 'BK', 'BV', 'EW']
#   Interface Coordinates:
#     (363.67327880859375, 350.6317138671875, 277.86151123046875)
#     Interface Energy: -8.03
#     (339.000732421875, 373.5777282714844, 277.7705078125)
#     Interface Energy: -8.80
#     (355.3064880371094, 370.4630432128906, 267.1522216796875)
#     Interface Energy: -187.63
#     (341.55755615234375, 377.1360168457031, 282.4796142578125)
#     Interface Energy: -34.00
# Chain BJ:
#   Center of Mass (COM): (368.9757080078125, 346.797119140625, 301.3142395019531)
#   Interfaces: ['AT', 'BI', 'BK']
#   Interface Coordinates:
#     (370.6317138671875, 345.56109619140625, 304.86175537109375)
#     Interface Energy: -187.63
#     (366.4976806640625, 352.2929992675781, 287.0090026855469)
#     Interface Energy: -8.03
#     (350.55859375, 351.640380859375, 308.1741943359375)
#     Interface Energy: -20.90
# Chain BK:
#   Center of Mass (COM): (335.5668640136719, 369.92181396484375, 307.6889953613281)
#   Interfaces: ['BI', 'BJ', 'EU', 'EW']
#   Interface Coordinates:
#     (332.7136535644531, 373.7586669921875, 285.0193176269531)
#     Interface Energy: -8.80
#     (346.5006103515625, 358.40521240234375, 306.8219909667969)
#     Interface Energy: -20.90
#     (331.87249755859375, 366.4116516113281, 330.4844970703125)
#     Interface Energy: -34.00
#     (333.675537109375, 373.13336181640625, 306.1913757324219)
#     Interface Energy: -225.98
# Chain BL:
#   Center of Mass (COM): (365.64129638671875, 188.5381622314453, 305.58001708984375)
#   Interfaces: ['BM', 'BN', 'EM', 'EZ']
#   Interface Coordinates:
#     (365.33526611328125, 188.0570068359375, 282.2122497558594)
#     Interface Energy: -8.03
#     (352.510986328125, 184.28199768066406, 313.1405029296875)
#     Interface Energy: -8.80
#     (370.0491943359375, 189.39105224609375, 305.74908447265625)
#     Interface Energy: -187.63
#     (353.32440185546875, 177.9029998779297, 313.2857971191406)
#     Interface Energy: -34.00
# Chain BM:
#   Center of Mass (COM): (356.71368408203125, 169.36224365234375, 269.2112731933594)
#   Interfaces: ['BL', 'BN', 'BX']
#   Interface Coordinates:
#     (363.5599670410156, 178.9533233642578, 279.3173522949219)
#     Interface Energy: -8.03
#     (339.88037109375, 167.08200073242188, 280.21881103515625)
#     Interface Energy: -20.90
#     (355.89752197265625, 166.59857177734375, 266.2874450683594)
#     Interface Energy: -187.63
# Chain BN:
#   Center of Mass (COM): (333.6437683105469, 162.96669006347656, 302.6545104980469)
#   Interfaces: ['BL', 'BM', 'EX', 'EZ']
#   Interface Coordinates:
#     (343.8556823730469, 180.27000427246094, 314.1903381347656)
#     Interface Energy: -8.80
#     (339.36419677734375, 166.047607421875, 288.1383972167969)
#     Interface Energy: -20.90
#     (318.1728210449219, 147.4213409423828, 294.61749267578125)
#     Interface Energy: -34.00
#     (333.85498046875, 163.15695190429688, 306.6610412597656)
#     Interface Energy: -225.98
# Chain BO:
#   Center of Mass (COM): (341.8984680175781, 309.0451354980469, 367.739501953125)
#   Interfaces: ['BP', 'BQ', 'EG', 'FC']
#   Interface Coordinates:
#     (329.8182373046875, 290.47552490234375, 375.1969909667969)
#     Interface Energy: -8.03
#     (333.7409973144531, 321.34698486328125, 362.28125)
#     Interface Energy: -8.80
#     (345.8125915527344, 307.39324951171875, 369.2013854980469)
#     Interface Energy: -187.63
#     (332.5003967285156, 324.4028015136719, 367.80419921875)
#     Interface Energy: -34.00
# Chain BP:
#   Center of Mass (COM): (310.565673828125, 291.96893310546875, 390.0279846191406)
#   Interfaces: ['BO', 'BQ', 'CA']
#   Interface Coordinates:
#     (324.121337890625, 293.2340087890625, 382.5686950683594)
#     Interface Energy: -8.03
#     (301.74639892578125, 307.21575927734375, 380.0545959472656)
#     Interface Energy: -20.90
#     (307.5894775390625, 291.23748779296875, 392.7593688964844)
#     Interface Energy: -187.63
# Chain BQ:
#   Center of Mass (COM): (306.6469421386719, 329.3514404296875, 373.33258056640625)
#   Interfaces: ['BO', 'BP', 'FA', 'FC']
#   Interface Coordinates:
#     (326.023681640625, 326.8769836425781, 360.8753356933594)
#     Interface Energy: -8.80
#     (304.968994140625, 314.2998046875, 378.18597412109375)
#     Interface Energy: -20.90
#     (285.3085021972656, 335.4033203125, 380.6571350097656)
#     Interface Energy: -34.00
#     (308.8799133300781, 332.432861328125, 372.04632568359375)
#     Interface Energy: -225.98
# Chain BR:
#   Center of Mass (COM): (391.0088195800781, 306.4167175292969, 239.1676788330078)
#   Interfaces: ['BS', 'BT', 'EJ', 'FF']
#   Interface Coordinates:
#     (379.2257385253906, 325.4674987792969, 245.84649658203125)
#     Interface Energy: -8.03
#     (385.48101806640625, 298.3710021972656, 226.82325744628906)
#     Interface Energy: -8.80
#     (394.39556884765625, 307.21563720703125, 242.00949096679688)
#     Interface Energy: -187.63
#     (388.1831970214844, 301.6942138671875, 222.0240020751953)
#     Interface Energy: -34.00
# Chain BS:
#   Center of Mass (COM): (371.52728271484375, 342.66888427734375, 230.42881774902344)
#   Interfaces: ['BR', 'BT', 'BU']
#   Interface Coordinates:
#     (379.1549987792969, 331.81298828125, 238.4883270263672)
#     Interface Energy: -8.03
#     (364.11700439453125, 329.7018127441406, 216.7659912109375)
#     Interface Energy: -20.90
#     (370.2590637207031, 346.16387939453125, 228.6884307861328)
#     Interface Energy: -187.63
# Chain BT:
#   Center of Mass (COM): (371.56103515625, 311.6814270019531, 203.38519287109375)
#   Interfaces: ['BR', 'BS', 'FD', 'FF']
#   Interface Coordinates:
#     (380.2440185546875, 296.8526611328125, 218.9250030517578)
#     Interface Energy: -8.80
#     (367.97882080078125, 323.6526184082031, 213.2238006591797)
#     Interface Energy: -20.90
#     (359.8301696777344, 321.17547607421875, 185.55699157714844)
#     Interface Energy: -34.00
#     (373.6765441894531, 308.4103088378906, 202.4065704345703)
#     Interface Energy: -225.98
# Chain BU:
#   Center of Mass (COM): (365.64129638671875, 347.46209716796875, 227.7399444580078)
#   Interfaces: ['BS', 'BV', 'BW', 'FI']
#   Interface Coordinates:
#     (370.04925537109375, 346.6089172363281, 227.57090759277344)
#     Interface Energy: -187.63
#     (365.33526611328125, 347.9429931640625, 251.10775756835938)
#     Interface Energy: -8.03
#     (352.510986328125, 351.718017578125, 220.17950439453125)
#     Interface Energy: -8.80
#     (353.32440185546875, 358.0970153808594, 220.03421020507812)
#     Interface Energy: -34.00
# Chain BV:
#   Center of Mass (COM): (356.71368408203125, 366.6374816894531, 264.1086120605469)
#   Interfaces: ['BI', 'BU', 'BW']
#   Interface Coordinates:
#     (355.8975524902344, 369.4013977050781, 267.0325622558594)
#     Interface Energy: -187.63
#     (363.5599670410156, 357.046630859375, 254.0026397705078)
#     Interface Energy: -8.03
#     (339.88037109375, 368.9179992675781, 253.1011962890625)
#     Interface Energy: -20.90
# Chain BW:
#   Center of Mass (COM): (333.6437683105469, 373.0332336425781, 230.66546630859375)
#   Interfaces: ['BU', 'BV', 'FG', 'FI']
#   Interface Coordinates:
#     (343.8556823730469, 355.72998046875, 219.1296844482422)
#     Interface Energy: -8.80
#     (339.36419677734375, 369.9524230957031, 245.18161010742188)
#     Interface Energy: -20.90
#     (318.1728210449219, 388.5786437988281, 238.70249938964844)
#     Interface Energy: -34.00
#     (333.85498046875, 372.84307861328125, 226.65890502929688)
#     Interface Energy: -225.98
# Chain BX:
#   Center of Mass (COM): (352.0885009765625, 166.6093292236328, 263.2216796875)
#   Interfaces: ['BM', 'BY', 'BZ', 'FL']
#   Interface Coordinates:
#     (355.3064270019531, 165.5369415283203, 266.167724609375)
#     Interface Energy: -187.63
#     (363.67327880859375, 185.3682403564453, 255.45849609375)
#     Interface Energy: -8.03
#     (339.000732421875, 162.4222412109375, 255.54949951171875)
#     Interface Energy: -8.80
#     (341.55755615234375, 158.86398315429688, 250.8404083251953)
#     Interface Energy: -34.00
# Chain BY:
#   Center of Mass (COM): (368.9757080078125, 189.2030792236328, 232.00575256347656)
#   Interfaces: ['BC', 'BX', 'BZ']
#   Interface Coordinates:
#     (370.6317138671875, 190.4388427734375, 228.4582061767578)
#     Interface Energy: -187.63
#     (366.4976806640625, 183.70701599121094, 246.31101989746094)
#     Interface Energy: -8.03
#     (350.55859375, 184.35958862304688, 225.1457977294922)
#     Interface Energy: -20.90
# Chain BZ:
#   Center of Mass (COM): (335.5668640136719, 166.07815551757812, 225.63075256347656)
#   Interfaces: ['BX', 'BY', 'FJ', 'FL']
#   Interface Coordinates:
#     (332.7136535644531, 162.2413330078125, 248.3006591796875)
#     Interface Energy: -8.80
#     (346.5006103515625, 177.5948028564453, 226.4980010986328)
#     Interface Energy: -20.90
#     (331.87249755859375, 169.5883331298828, 202.8354949951172)
#     Interface Energy: -34.00
#     (333.675537109375, 162.86659240722656, 227.12869262695312)
#     Interface Energy: -225.98
# Chain CA:
#   Center of Mass (COM): (302.9781494140625, 289.9289245605469, 391.7936096191406)
#   Interfaces: ['BP', 'CB', 'CC', 'FO']
#   Interface Coordinates:
#     (306.7234191894531, 291.8540954589844, 393.3597412109375)
#     Interface Energy: -187.63
#     (314.2659912109375, 270.6887512207031, 384.8087463378906)
#     Interface Energy: -8.03
#     (287.260498046875, 289.8597412109375, 391.00775146484375)
#     Interface Energy: -8.80
#     (285.87457275390625, 287.03900146484375, 396.62042236328125)
#     Interface Energy: -34.00
# Chain CB:
#   Center of Mass (COM): (308.0143737792969, 248.1590576171875, 391.6047668457031)
#   Interfaces: ['BF', 'CA', 'CC']
#   Interface Coordinates:
#     (307.9621276855469, 244.15975952148438, 392.52911376953125)
#     Interface Energy: -187.63
#     (311.4640197753906, 263.246337890625, 390.3916931152344)
#     Interface Energy: -8.03
#     (288.1875915527344, 250.72238159179688, 388.43438720703125)
#     Interface Energy: -20.90
# Chain CC:
#   Center of Mass (COM): (270.65264892578125, 264.888427734375, 395.57891845703125)
#   Interfaces: ['CA', 'CB', 'FM', 'FO']
#   Interface Coordinates:
#     (278.4933166503906, 286.0286560058594, 390.2506408691406)
#     Interface Energy: -8.80
#     (283.4906311035156, 256.4527893066406, 391.46038818359375)
#     Interface Energy: -20.90
#     (257.3509826660156, 245.83299255371094, 397.9358215332031)
#     Interface Energy: -34.00
#     (268.8789367675781, 268.290283203125, 396.768310546875)
#     Interface Energy: -225.98
# Chain CD:
#   Center of Mass (COM): (240.50759887695312, 144.99159240722656, 228.2432098388672)
#   Interfaces: ['CE', 'CF', 'DX', 'FR']
#   Interface Coordinates:
#     (247.18649291992188, 156.77426147460938, 209.1925048828125)
#     Interface Energy: -8.03
#     (228.1632537841797, 150.5189971923828, 236.28900146484375)
#     Interface Energy: -8.80
#     (243.34945678710938, 141.60452270507812, 227.4442901611328)
#     Interface Energy: -187.63
#     (223.364013671875, 147.81680297851562, 232.96578979492188)
#     Interface Energy: -34.00
# Chain CE:
#   Center of Mass (COM): (231.76876831054688, 164.4727783203125, 191.99114990234375)
#   Interfaces: ['CD', 'CF', 'DK']
#   Interface Coordinates:
#     (239.8283233642578, 156.84500122070312, 202.8470001220703)
#     Interface Energy: -8.03
#     (218.1060028076172, 171.8829803466797, 204.9582061767578)
#     Interface Energy: -20.90
#     (230.0283966064453, 165.7408905029297, 188.49612426757812)
#     Interface Energy: -187.63
# Chain CF:
#   Center of Mass (COM): (204.72500610351562, 164.43870544433594, 222.97845458984375)
#   Interfaces: ['CD', 'CE', 'FP', 'FR']
#   Interface Coordinates:
#     (220.2650146484375, 155.75599670410156, 237.8073272705078)
#     Interface Energy: -8.80
#     (214.5637969970703, 168.02120971679688, 211.0074005126953)
#     Interface Energy: -20.90
#     (186.89698791503906, 176.1698455810547, 213.4844970703125)
#     Interface Energy: -34.00
#     (203.74655151367188, 162.32339477539062, 226.24974060058594)
#     Interface Energy: -225.98
# Chain CG:
#   Center of Mass (COM): (188.5381622314453, 306.9198303222656, 364.3011474609375)
#   Interfaces: ['CH', 'CI', 'EA', 'FU']
#   Interface Coordinates:
#     (188.0570068359375, 283.55224609375, 363.9952392578125)
#     Interface Energy: -8.03
#     (184.28199768066406, 314.4804992675781, 351.1709899902344)
#     Interface Energy: -8.80
#     (189.39105224609375, 307.0890808105469, 368.70916748046875)
#     Interface Energy: -187.63
#     (177.9029998779297, 314.62579345703125, 351.9844055175781)
#     Interface Energy: -34.00
# Chain CH:
#   Center of Mass (COM): (169.36224365234375, 270.5511169433594, 355.3736267089844)
#   Interfaces: ['CG', 'CI', 'DE']
#   Interface Coordinates:
#     (178.9533233642578, 280.6573181152344, 362.2200012207031)
#     Interface Energy: -8.03
#     (167.08200073242188, 281.55877685546875, 338.5404052734375)
#     Interface Energy: -20.90
#     (166.59857177734375, 267.6274108886719, 354.5574951171875)
#     Interface Energy: -187.63
# Chain CI:
#   Center of Mass (COM): (162.96669006347656, 303.99444580078125, 332.303955078125)
#   Interfaces: ['CG', 'CH', 'FS', 'FU']
#   Interface Coordinates:
#     (180.27000427246094, 315.5303649902344, 342.5156555175781)
#     Interface Energy: -8.80
#     (166.047607421875, 289.4784240722656, 338.024169921875)
#     Interface Energy: -20.90
#     (147.4213409423828, 295.95751953125, 316.8328552246094)
#     Interface Energy: -34.00
#     (163.15695190429688, 308.0010986328125, 332.51495361328125)
#     Interface Energy: -225.98
# Chain CJ:
#   Center of Mass (COM): (264.5614318847656, 352.0885009765625, 165.26942443847656)
#   Interfaces: ['CK', 'CL', 'ED', 'FX']
#   Interface Coordinates:
#     (256.7984924316406, 363.67327880859375, 184.02825927734375)
#     Interface Energy: -8.03
#     (256.8894958496094, 339.000732421875, 161.08224487304688)
#     Interface Energy: -8.80
#     (267.50775146484375, 355.3064880371094, 164.1969451904297)
#     Interface Energy: -187.63
#     (252.18038940429688, 341.55755615234375, 157.5240020751953)
#     Interface Energy: -34.00
# Chain CK:
#   Center of Mass (COM): (233.3456573486328, 368.9757080078125, 187.8631591796875)
#   Interfaces: ['CJ', 'CL', 'DH']
#   Interface Coordinates:
#     (247.6510009765625, 366.4976806640625, 182.36700439453125)
#     Interface Energy: -8.03
#     (226.4857940673828, 350.55859375, 183.0196075439453)
#     Interface Energy: -20.90
#     (229.7982635498047, 370.6316833496094, 189.09884643554688)
#     Interface Energy: -187.63
# Chain CL:
#   Center of Mass (COM): (226.97091674804688, 335.5668640136719, 164.738037109375)
#   Interfaces: ['CJ', 'CK', 'FV', 'FX']
#   Interface Coordinates:
#     (249.6406707763672, 332.7136535644531, 160.90133666992188)
#     Interface Energy: -8.80
#     (227.83798217773438, 346.5006103515625, 176.2548065185547)
#     Interface Energy: -20.90
#     (204.1754913330078, 331.87249755859375, 168.2483367919922)
#     Interface Energy: -34.00
#     (228.4686279296875, 333.675537109375, 161.526611328125)
#     Interface Energy: -225.98
# Chain CM:
#   Center of Mass (COM): (240.50759887695312, 391.0088195800781, 305.07659912109375)
#   Interfaces: ['CN', 'CO', 'DO', 'GA']
#   Interface Coordinates:
#     (247.18649291992188, 379.2257385253906, 324.12750244140625)
#     Interface Energy: -8.03
#     (228.1632537841797, 385.48101806640625, 297.031005859375)
#     Interface Energy: -8.80
#     (243.34945678710938, 394.39556884765625, 305.8757019042969)
#     Interface Energy: -187.63
#     (223.364013671875, 388.1831970214844, 300.35418701171875)
#     Interface Energy: -34.00
# Chain CN:
#   Center of Mass (COM): (231.76876831054688, 371.52728271484375, 341.3286437988281)
#   Interfaces: ['AN', 'CM', 'CO']
#   Interface Coordinates:
#     (230.0283660888672, 370.25909423828125, 344.82379150390625)
#     Interface Energy: -187.63
#     (239.8283233642578, 379.1549987792969, 330.4729919433594)
#     Interface Energy: -8.03
#     (218.1060028076172, 364.11700439453125, 328.36175537109375)
#     Interface Energy: -20.90
# Chain CO:
#   Center of Mass (COM): (204.72500610351562, 371.56103515625, 310.3417053222656)
#   Interfaces: ['CM', 'CN', 'FY', 'GA']
#   Interface Coordinates:
#     (220.2650146484375, 380.2440185546875, 295.5126647949219)
#     Interface Energy: -8.80
#     (214.5637969970703, 367.97882080078125, 322.3125915527344)
#     Interface Energy: -20.90
#     (186.89698791503906, 359.8301696777344, 319.83551025390625)
#     Interface Energy: -34.00
#     (203.74655151367188, 373.6765441894531, 307.0702819824219)
#     Interface Energy: -225.98
# Chain CP:
#   Center of Mass (COM): (302.9781494140625, 246.0711212158203, 141.52645874023438)
#   Interfaces: ['CQ', 'CR', 'DR', 'GD']
#   Interface Coordinates:
#     (314.2659912109375, 265.3112487792969, 148.51126098632812)
#     Interface Energy: -8.03
#     (287.260498046875, 246.14024353027344, 142.312255859375)
#     Interface Energy: -8.80
#     (306.7234191894531, 244.14588928222656, 139.96029663085938)
#     Interface Energy: -187.63
#     (285.87457275390625, 248.9609832763672, 136.69961547851562)
#     Interface Energy: -34.00
# Chain CQ:
#   Center of Mass (COM): (308.0143737792969, 287.8408508300781, 141.7153778076172)
#   Interfaces: ['AQ', 'CP', 'CR']
#   Interface Coordinates:
#     (307.9621276855469, 291.84027099609375, 140.79086303710938)
#     Interface Energy: -187.63
#     (311.4640197753906, 272.753662109375, 142.92832946777344)
#     Interface Energy: -8.03
#     (288.1875915527344, 285.2776184082031, 144.8856201171875)
#     Interface Energy: -20.90
# Chain CR:
#   Center of Mass (COM): (270.65264892578125, 271.1116027832031, 137.7414093017578)
#   Interfaces: ['CP', 'CQ', 'GB', 'GD']
#   Interface Coordinates:
#     (278.4933166503906, 249.97132873535156, 143.0693359375)
#     Interface Energy: -8.80
#     (283.4906311035156, 279.54718017578125, 141.85960388183594)
#     Interface Energy: -20.90
#     (257.3509826660156, 290.1670227050781, 135.38417053222656)
#     Interface Energy: -34.00
#     (268.8789367675781, 267.709716796875, 136.55162048339844)
#     Interface Energy: -225.98
# Chain CS:
#   Center of Mass (COM): (226.95472717285156, 166.92034912109375, 340.5582580566406)
#   Interfaces: ['CT', 'CU', 'DU', 'GG']
#   Interface Coordinates:
#     (245.5244903564453, 159.46299743652344, 328.4782409667969)
#     Interface Energy: -8.03
#     (214.6529998779297, 172.37875366210938, 332.4010009765625)
#     Interface Energy: -8.80
#     (228.60671997070312, 165.45864868164062, 344.4725646972656)
#     Interface Energy: -187.63
#     (211.5972137451172, 166.85580444335938, 331.160400390625)
#     Interface Energy: -34.00
# Chain CT:
#   Center of Mass (COM): (244.0312042236328, 144.632080078125, 309.22576904296875)
#   Interfaces: ['AK', 'CS', 'CU']
#   Interface Coordinates:
#     (244.76254272460938, 141.90060424804688, 306.24957275390625)
#     Interface Energy: -187.63
#     (242.7659912109375, 152.09132385253906, 322.7813415527344)
#     Interface Energy: -8.03
#     (228.7841796875, 154.60540771484375, 300.40643310546875)
#     Interface Energy: -20.90
# Chain CU:
#   Center of Mass (COM): (206.6483917236328, 161.3271026611328, 305.3072204589844)
#   Interfaces: ['CS', 'CT', 'GE', 'GG']
#   Interface Coordinates:
#     (209.1230010986328, 173.78466796875, 324.6836853027344)
#     Interface Energy: -8.80
#     (221.7001953125, 156.4739990234375, 303.6289978027344)
#     Interface Energy: -20.90
#     (200.5966796875, 154.00283813476562, 283.9684753417969)
#     Interface Energy: -34.00
#     (203.567138671875, 162.6136932373047, 307.5399475097656)
#     Interface Energy: -225.98
# Chain CV:
#   Center of Mass (COM): (166.6093292236328, 271.4385681152344, 182.5714874267578)
#   Interfaces: ['CW', 'CX', 'GJ', 'GL']
#   Interface Coordinates:
#     (185.3682403564453, 279.2015075683594, 170.9867401123047)
#     Interface Energy: -8.03
#     (162.4222412109375, 279.1105041503906, 195.6592559814453)
#     Interface Energy: -8.80
#     (158.86398315429688, 283.819580078125, 193.10238647460938)
#     Interface Energy: -34.00
#     (165.5369415283203, 268.49224853515625, 179.35354614257812)
#     Interface Energy: -187.63
# Chain CW:
#   Center of Mass (COM): (189.2030792236328, 302.6544189453125, 165.68421936035156)
#   Interfaces: ['CV', 'CX', 'FV']
#   Interface Coordinates:
#     (183.70701599121094, 288.3489990234375, 168.16233825683594)
#     Interface Energy: -8.03
#     (184.35958862304688, 309.51422119140625, 184.1013946533203)
#     Interface Energy: -20.90
#     (190.43882751464844, 306.20172119140625, 164.0283203125)
#     Interface Energy: -187.63
# Chain CX:
#   Center of Mass (COM): (166.07815551757812, 309.0291442871094, 199.0932159423828)
#   Interfaces: ['CV', 'CW', 'GH', 'GJ']
#   Interface Coordinates:
#     (162.2413330078125, 286.3593444824219, 201.9463348388672)
#     Interface Energy: -8.80
#     (177.5948028564453, 308.1620178222656, 188.15939331054688)
#     Interface Energy: -20.90
#     (169.5883331298828, 331.8244934082031, 202.7875213623047)
#     Interface Energy: -34.00
#     (162.86659240722656, 307.5313720703125, 200.98443603515625)
#     Interface Energy: -225.98
# Chain CY:
#   Center of Mass (COM): (144.99159240722656, 229.58334350585938, 239.1676788330078)
#   Interfaces: ['CZ', 'DA', 'GM', 'GO']
#   Interface Coordinates:
#     (156.77426147460938, 210.53250122070312, 245.84649658203125)
#     Interface Energy: -8.03
#     (150.5189971923828, 237.62899780273438, 226.82325744628906)
#     Interface Energy: -8.80
#     (147.81680297851562, 234.30581665039062, 222.0240020751953)
#     Interface Energy: -34.00
#     (141.60452270507812, 228.7843017578125, 242.00949096679688)
#     Interface Energy: -187.63
# Chain CZ:
#   Center of Mass (COM): (164.4727783203125, 193.33108520507812, 230.42881774902344)
#   Interfaces: ['CY', 'DA', 'FP']
#   Interface Coordinates:
#     (156.84500122070312, 204.18699645996094, 238.4883270263672)
#     Interface Energy: -8.03
#     (171.8829803466797, 206.29818725585938, 216.7659912109375)
#     Interface Energy: -20.90
#     (165.7408905029297, 189.83615112304688, 228.6884307861328)
#     Interface Energy: -187.63
# Chain DA:
#   Center of Mass (COM): (164.43870544433594, 224.31837463378906, 203.38519287109375)
#   Interfaces: ['CY', 'CZ', 'GK', 'GM']
#   Interface Coordinates:
#     (155.75599670410156, 239.1473388671875, 218.9250030517578)
#     Interface Energy: -8.80
#     (168.02120971679688, 212.347412109375, 213.2238006591797)
#     Interface Energy: -20.90
#     (176.1698455810547, 214.82447814941406, 185.55699157714844)
#     Interface Energy: -34.00
#     (162.32339477539062, 227.58970642089844, 202.4065704345703)
#     Interface Energy: -225.98
# Chain DB:
#   Center of Mass (COM): (142.86654663085938, 302.9781494140625, 244.73123168945312)
#   Interfaces: ['DC', 'DD', 'GI', 'GP']
#   Interface Coordinates:
#     (149.85125732421875, 314.2659912109375, 263.97125244140625)
#     Interface Energy: -8.03
#     (143.65225219726562, 287.260498046875, 244.80023193359375)
#     Interface Energy: -8.80
#     (141.30027770996094, 306.7234191894531, 242.805908203125)
#     Interface Energy: -187.63
#     (138.03958129882812, 285.87457275390625, 247.62100219726562)
#     Interface Energy: -34.00
# Chain DC:
#   Center of Mass (COM): (143.05526733398438, 308.0143737792969, 286.5009460449219)
#   Interfaces: ['DB', 'DD', 'FS']
#   Interface Coordinates:
#     (144.26834106445312, 311.4640197753906, 271.4136657714844)
#     Interface Energy: -8.03
#     (146.22560119628906, 288.1875915527344, 283.93756103515625)
#     Interface Energy: -20.90
#     (142.13087463378906, 307.9620056152344, 290.50030517578125)
#     Interface Energy: -187.63
# Chain DD:
#   Center of Mass (COM): (139.08131408691406, 270.65264892578125, 269.77142333984375)
#   Interfaces: ['DB', 'DC', 'GN', 'GP']
#   Interface Coordinates:
#     (144.40933227539062, 278.4933166503906, 248.63133239746094)
#     Interface Energy: -8.80
#     (143.19961547851562, 283.4906311035156, 278.20721435546875)
#     Interface Energy: -20.90
#     (136.7241668701172, 257.3509826660156, 288.8269958496094)
#     Interface Energy: -34.00
#     (137.89163208007812, 268.8789367675781, 266.36968994140625)
#     Interface Energy: -225.98
# Chain DE:
#   Center of Mass (COM): (166.6093292236328, 264.5614318847656, 350.748291015625)
#   Interfaces: ['CH', 'DF', 'DG', 'GS']
#   Interface Coordinates:
#     (165.5369415283203, 267.50775146484375, 353.96649169921875)
#     Interface Energy: -187.63
#     (185.3682403564453, 256.7984924316406, 362.3332214355469)
#     Interface Energy: -8.03
#     (162.4222412109375, 256.8894958496094, 337.6607666015625)
#     Interface Energy: -8.80
#     (158.86398315429688, 252.18038940429688, 340.21759033203125)
#     Interface Energy: -34.00
# Chain DF:
#   Center of Mass (COM): (189.2030792236328, 233.3456573486328, 367.6356506347656)
#   Interfaces: ['AH', 'DE', 'DG']
#   Interface Coordinates:
#     (190.4388427734375, 229.7982177734375, 369.2916259765625)
#     Interface Energy: -187.63
#     (183.70701599121094, 247.6510009765625, 365.1576843261719)
#     Interface Energy: -8.03
#     (184.35958862304688, 226.4857940673828, 349.21856689453125)
#     Interface Energy: -20.90
# Chain DG:
#   Center of Mass (COM): (166.07815551757812, 226.97091674804688, 334.2269592285156)
#   Interfaces: ['DE', 'DF', 'GQ', 'GS']
#   Interface Coordinates:
#     (162.2413330078125, 249.6406707763672, 331.3736572265625)
#     Interface Energy: -8.80
#     (177.5948028564453, 227.83798217773438, 345.16058349609375)
#     Interface Energy: -20.90
#     (169.5883331298828, 204.1754913330078, 330.5325012207031)
#     Interface Energy: -34.00
#     (162.86659240722656, 228.4686279296875, 332.33551025390625)
#     Interface Energy: -225.98
# Chain DH:
#   Center of Mass (COM): (226.95472717285156, 369.0795593261719, 192.76177978515625)
#   Interfaces: ['CK', 'DI', 'DJ', 'GV']
#   Interface Coordinates:
#     (228.60671997070312, 370.54132080078125, 188.84744262695312)
#     Interface Energy: -187.63
#     (245.5244903564453, 376.5369873046875, 204.8417510986328)
#     Interface Energy: -8.03
#     (214.6529998779297, 363.62127685546875, 200.9189910888672)
#     Interface Energy: -8.80
#     (211.5972137451172, 369.1441955566406, 202.15960693359375)
#     Interface Energy: -34.00
# Chain DI:
#   Center of Mass (COM): (244.0312042236328, 391.3680725097656, 224.09429931640625)
#   Interfaces: ['AB', 'DH', 'DJ']
#   Interface Coordinates:
#     (244.76254272460938, 394.0993347167969, 227.0704345703125)
#     Interface Energy: -187.63
#     (242.7659912109375, 383.90869140625, 210.5386505126953)
#     Interface Energy: -8.03
#     (228.7841796875, 381.39459228515625, 232.91360473632812)
#     Interface Energy: -20.90
# Chain DJ:
#   Center of Mass (COM): (206.6483917236328, 374.6727294921875, 228.01290893554688)
#   Interfaces: ['DH', 'DI', 'GT', 'GV']
#   Interface Coordinates:
#     (209.1230010986328, 362.21533203125, 208.63633728027344)
#     Interface Energy: -8.80
#     (221.7001953125, 379.5260009765625, 229.6909942626953)
#     Interface Energy: -20.90
#     (200.5966796875, 381.9971618652344, 249.35150146484375)
#     Interface Energy: -34.00
#     (203.567138671875, 373.3863220214844, 225.78001403808594)
#     Interface Energy: -225.98
# Chain DK:
#   Center of Mass (COM): (229.08013916015625, 170.3588104248047, 187.19808959960938)
#   Interfaces: ['CE', 'DL', 'DM', 'GY']
#   Interface Coordinates:
#     (228.91090393066406, 165.9508514404297, 188.05108642578125)
#     Interface Energy: -187.63
#     (252.44775390625, 170.6647491455078, 186.7169952392578)
#     Interface Energy: -8.03
#     (221.51950073242188, 183.48899841308594, 182.94198608398438)
#     Interface Energy: -8.80
#     (221.3741912841797, 182.67559814453125, 176.56298828125)
#     Interface Energy: -34.00
# Chain DL:
#   Center of Mass (COM): (265.4488830566406, 179.28646850585938, 168.02235412597656)
#   Interfaces: ['AE', 'DK', 'DM']
#   Interface Coordinates:
#     (268.3725891113281, 180.1024627685547, 165.25857543945312)
#     Interface Energy: -187.63
#     (255.34266662597656, 172.44000244140625, 177.61334228515625)
#     Interface Energy: -8.03
#     (254.4412078857422, 196.11959838867188, 165.74200439453125)
#     Interface Energy: -20.90
# Chain DM:
#   Center of Mass (COM): (232.00552368164062, 202.3562469482422, 161.62661743164062)
#   Interfaces: ['DK', 'DL', 'GW', 'GY']
#   Interface Coordinates:
#     (220.46966552734375, 192.1443328857422, 178.9300079345703)
#     Interface Energy: -8.80
#     (246.5216064453125, 196.6357879638672, 164.70761108398438)
#     Interface Energy: -20.90
#     (240.04249572753906, 217.82716369628906, 146.08132934570312)
#     Interface Energy: -34.00
#     (227.9989471435547, 202.14505004882812, 161.81690979003906)
#     Interface Energy: -225.98
# Chain DN:
#   Center of Mass (COM): (289.9289245605469, 393.1337585449219, 301.6383972167969)
#   Interfaces: ['AD', 'DO', 'DP', 'EV']
#   Interface Coordinates:
#     (287.03900146484375, 397.96038818359375, 284.53460693359375)
#     Interface Energy: -34.00
#     (270.6887512207031, 386.1487731933594, 312.9259948730469)
#     Interface Energy: -8.03
#     (289.8597412109375, 392.3477783203125, 285.9205322265625)
#     Interface Energy: -8.80
#     (291.85406494140625, 394.69970703125, 305.38348388671875)
#     Interface Energy: -187.63
# Chain DO:
#   Center of Mass (COM): (248.1590576171875, 392.9450988769531, 306.67462158203125)
#   Interfaces: ['CM', 'DN', 'DP']
#   Interface Coordinates:
#     (244.15975952148438, 393.8691711425781, 306.62213134765625)
#     Interface Energy: -187.63
#     (263.246337890625, 391.731689453125, 310.1239929199219)
#     Interface Energy: -8.03
#     (250.72238159179688, 389.7743835449219, 286.84759521484375)
#     Interface Energy: -20.90
# Chain DP:
#   Center of Mass (COM): (264.888427734375, 396.9188537597656, 269.31268310546875)
#   Interfaces: ['AB', 'AD', 'DN', 'DO']
#   Interface Coordinates:
#     (245.8330078125, 399.2758483886719, 256.0110168457031)
#     Interface Energy: -34.00
#     (268.290283203125, 398.10833740234375, 267.5389099121094)
#     Interface Energy: -225.98
#     (286.0286560058594, 391.5906677246094, 277.1533203125)
#     Interface Energy: -8.80
#     (256.4527893066406, 392.8004150390625, 282.15057373046875)
#     Interface Energy: -20.90
# Chain DQ:
#   Center of Mass (COM): (341.8984680175781, 226.95472717285156, 165.58033752441406)
#   Interfaces: ['AG', 'DR', 'DS', 'EP']
#   Interface Coordinates:
#     (332.5003967285156, 211.59719848632812, 165.5157928466797)
#     Interface Energy: -34.00
#     (329.8182373046875, 245.5244903564453, 158.1230010986328)
#     Interface Energy: -8.03
#     (333.7409973144531, 214.6529998779297, 171.03875732421875)
#     Interface Energy: -8.80
#     (345.8125915527344, 228.60671997070312, 164.11863708496094)
#     Interface Energy: -187.63
# Chain DR:
#   Center of Mass (COM): (310.565673828125, 244.0312042236328, 143.2920684814453)
#   Interfaces: ['CP', 'DQ', 'DS']
#   Interface Coordinates:
#     (307.5894775390625, 244.76254272460938, 140.5606231689453)
#     Interface Energy: -187.63
#     (324.121337890625, 242.7659912109375, 150.75132751464844)
#     Interface Energy: -8.03
#     (301.74639892578125, 228.7841796875, 153.26539611816406)
#     Interface Energy: -20.90
# Chain DS:
#   Center of Mass (COM): (306.6469421386719, 206.6483917236328, 159.98719787597656)
#   Interfaces: ['AE', 'AG', 'DQ', 'DR']
#   Interface Coordinates:
#     (285.3085021972656, 200.59666442871094, 152.662841796875)
#     Interface Energy: -34.00
#     (308.8799133300781, 203.567138671875, 161.27369689941406)
#     Interface Energy: -225.98
#     (326.023681640625, 209.1230010986328, 172.4446563720703)
#     Interface Energy: -8.80
#     (304.968994140625, 221.7001953125, 155.13400268554688)
#     Interface Energy: -20.90
# Chain DT:
#   Center of Mass (COM): (264.5614318847656, 183.91168212890625, 368.0507507324219)
#   Interfaces: ['AJ', 'DU', 'DV', 'ES']
#   Interface Coordinates:
#     (252.18038940429688, 194.44241333007812, 375.7959899902344)
#     Interface Energy: -34.00
#     (256.7984924316406, 172.32675170898438, 349.291748046875)
#     Interface Energy: -8.03
#     (256.8894958496094, 196.99923706054688, 372.2377624511719)
#     Interface Energy: -8.80
#     (267.50775146484375, 180.69354248046875, 369.12310791015625)
#     Interface Energy: -187.63
# Chain DU:
#   Center of Mass (COM): (233.3456573486328, 167.02398681640625, 345.4566955566406)
#   Interfaces: ['CS', 'DT', 'DV']
#   Interface Coordinates:
#     (229.7982177734375, 165.36831665039062, 344.2211608886719)
# ...
#     (141.60452270507812, 307.21575927734375, 291.3105773925781)
#     Interface Energy: -187.63
#     (156.77426147460938, 325.4674987792969, 287.4734802246094)
#     Interface Energy: -8.03
#     (150.5189971923828, 298.3710021972656, 306.49676513671875)
#     Interface Energy: -8.80
# Chain FT:
#   Center of Mass (COM): (164.4727783203125, 342.66888427734375, 302.89117431640625)
#   Interfaces: ['FS', 'FU', 'FY']
#   Interface Coordinates:
#     (156.84500122070312, 331.81298828125, 294.8316955566406)
#     Interface Energy: -8.03
#     (171.8829803466797, 329.7018127441406, 316.55401611328125)
#     Interface Energy: -20.90
#     (165.7408905029297, 346.16387939453125, 304.6316223144531)
#     Interface Energy: -187.63
# Chain FU:
#   Center of Mass (COM): (164.43870544433594, 311.6814270019531, 329.93505859375)
#   Interfaces: ['CG', 'CI', 'FS', 'FT']
#   Interface Coordinates:
#     (176.1698455810547, 321.1755065917969, 347.7630310058594)
#     Interface Energy: -34.00
#     (162.32339477539062, 308.4102478027344, 330.91339111328125)
#     Interface Energy: -225.98
#     (155.75599670410156, 296.8526611328125, 314.3949890136719)
#     Interface Energy: -8.80
#     (168.02120971679688, 323.6526184082031, 320.09619140625)
#     Interface Energy: -20.90
# Chain FV:
#   Center of Mass (COM): (194.10177612304688, 309.0451354980469, 165.58033752441406)
#   Interfaces: ['CL', 'CW', 'FW', 'FX']
#   Interface Coordinates:
#     (203.49960327148438, 324.4028015136719, 165.5157928466797)
#     Interface Energy: -34.00
#     (190.18743896484375, 307.39324951171875, 164.11863708496094)
#     Interface Energy: -187.63
#     (206.1817626953125, 290.47552490234375, 158.1230010986328)
#     Interface Energy: -8.03
#     (202.25900268554688, 321.34698486328125, 171.03875732421875)
#     Interface Energy: -8.80
# Chain FW:
#   Center of Mass (COM): (225.43421936035156, 291.96893310546875, 143.2920684814453)
#   Interfaces: ['FV', 'FX', 'GB']
#   Interface Coordinates:
#     (211.878662109375, 293.2340087890625, 150.75132751464844)
#     Interface Energy: -8.03
#     (234.2535858154297, 307.21575927734375, 153.26539611816406)
#     Interface Energy: -20.90
#     (228.41049194335938, 291.23748779296875, 140.56060791015625)
#     Interface Energy: -187.63
# Chain FX:
#   Center of Mass (COM): (229.35301208496094, 329.3514404296875, 159.98719787597656)
#   Interfaces: ['CJ', 'CL', 'FV', 'FW']
#   Interface Coordinates:
#     (250.69151306152344, 335.4033203125, 152.662841796875)
#     Interface Energy: -34.00
#     (227.1200408935547, 332.432861328125, 161.27369689941406)
#     Interface Energy: -225.98
#     (209.97633361816406, 326.8769836425781, 172.4446563720703)
#     Interface Energy: -8.80
#     (231.031005859375, 314.2998046875, 155.13400268554688)
#     Interface Energy: -20.90
# Chain FY:
#   Center of Mass (COM): (170.3588104248047, 347.46209716796875, 305.58001708984375)
#   Interfaces: ['CO', 'FT', 'FZ', 'GA']
#   Interface Coordinates:
#     (182.6755828857422, 358.09698486328125, 313.2857971191406)
#     Interface Energy: -34.00
#     (165.9508514404297, 346.6089172363281, 305.74908447265625)
#     Interface Energy: -187.63
#     (170.6647491455078, 347.9429931640625, 282.2122497558594)
#     Interface Energy: -8.03
#     (183.48899841308594, 351.718017578125, 313.1405029296875)
#     Interface Energy: -8.80
# Chain FZ:
#   Center of Mass (COM): (179.28646850585938, 366.6374816894531, 269.2112731933594)
#   Interfaces: ['FY', 'GA', 'GT']
#   Interface Coordinates:
#     (172.44000244140625, 357.046630859375, 279.3173522949219)
#     Interface Energy: -8.03
#     (196.11959838867188, 368.9179992675781, 280.21881103515625)
#     Interface Energy: -20.90
#     (180.10247802734375, 369.40142822265625, 266.2874450683594)
#     Interface Energy: -187.63
# Chain GA:
#   Center of Mass (COM): (202.3562469482422, 373.0332336425781, 302.6545104980469)
#   Interfaces: ['CM', 'CO', 'FY', 'FZ']
#   Interface Coordinates:
#     (217.82716369628906, 388.5786437988281, 294.6175231933594)
#     Interface Energy: -34.00
#     (202.1450653076172, 372.84307861328125, 306.6611022949219)
#     Interface Energy: -225.98
#     (192.1443328857422, 355.72998046875, 314.1903381347656)
#     Interface Energy: -8.80
#     (196.6357879638672, 369.9524230957031, 288.1383972167969)
#     Interface Energy: -20.90
# Chain GB:
#   Center of Mass (COM): (233.02186584472656, 289.9289245605469, 141.52645874023438)
#   Interfaces: ['CR', 'FW', 'GC', 'GD']
#   Interface Coordinates:
#     (250.1254119873047, 287.03900146484375, 136.69960021972656)
#     Interface Energy: -34.00
#     (229.2765350341797, 291.8540954589844, 139.9602813720703)
#     Interface Energy: -187.63
#     (221.73399353027344, 270.6887512207031, 148.51126098632812)
#     Interface Energy: -8.03
#     (248.739501953125, 289.8597412109375, 142.312255859375)
#     Interface Energy: -8.80
# Chain GC:
#   Center of Mass (COM): (227.9853973388672, 248.1590576171875, 141.7153778076172)
#   Interfaces: ['GB', 'GD', 'GW']
#   Interface Coordinates:
#     (224.53599548339844, 263.246337890625, 142.92832946777344)
#     Interface Energy: -8.03
#     (247.81240844726562, 250.72238159179688, 144.8856201171875)
#     Interface Energy: -20.90
#     (228.0378875732422, 244.1597137451172, 140.79087829589844)
#     Interface Energy: -187.63
# Chain GD:
#   Center of Mass (COM): (265.34735107421875, 264.888427734375, 137.7414093017578)
#   Interfaces: ['CP', 'CR', 'GB', 'GC']
#   Interface Coordinates:
#     (278.6490173339844, 245.8330078125, 135.3841552734375)
#     Interface Energy: -34.00
#     (267.12109375, 268.290283203125, 136.55165100097656)
#     Interface Energy: -225.98
#     (257.5066833496094, 286.0286560058594, 143.0693359375)
#     Interface Energy: -8.80
#     (252.50936889648438, 256.4527893066406, 141.85960388183594)
#     Interface Energy: -20.90
# Chain GE:
#   Center of Mass (COM): (183.91168212890625, 166.6093292236328, 270.09857177734375)
#   Interfaces: ['CU', 'FQ', 'GF', 'GG']
#   Interface Coordinates:
#     (194.44241333007812, 158.86399841308594, 282.4795837402344)
#     Interface Energy: -34.00
#     (180.6935272216797, 165.5369415283203, 267.15228271484375)
#     Interface Energy: -187.63
#     (172.32675170898438, 185.3682403564453, 277.86151123046875)
#     Interface Energy: -8.03
#     (196.99923706054688, 162.4222412109375, 277.7705078125)
#     Interface Energy: -8.80
# Chain GF:
#   Center of Mass (COM): (167.02398681640625, 189.2030792236328, 301.3142395019531)
#   Interfaces: ['GE', 'GG', 'GQ']
#   Interface Coordinates:
#     (169.50233459472656, 183.70701599121094, 287.0090026855469)
#     Interface Energy: -8.03
#     (185.44139099121094, 184.35958862304688, 308.1741943359375)
#     Interface Energy: -20.90
#     (165.3683319091797, 190.43882751464844, 304.8617858886719)
#     Interface Energy: -187.63
# Chain GG:
#   Center of Mass (COM): (200.433349609375, 166.07815551757812, 307.6889953613281)
#   Interfaces: ['CS', 'CU', 'GE', 'GF']
#   Interface Coordinates:
#     (204.1275177001953, 169.5883331298828, 330.4844665527344)
#     Interface Energy: -34.00
#     (202.32447814941406, 162.86660766601562, 306.1913146972656)
#     Interface Energy: -225.98
#     (203.2863311767578, 162.2413330078125, 285.0193176269531)
#     Interface Energy: -8.80
#     (189.4993896484375, 177.5948028564453, 306.8219909667969)
#     Interface Energy: -20.90
# Chain GH:
#   Center of Mass (COM): (166.92034912109375, 341.8984680175781, 225.6148681640625)
#   Interfaces: ['CX', 'GI', 'GJ', 'GU']
#   Interface Coordinates:
#     (166.85580444335938, 332.5003967285156, 210.2572021484375)
#     Interface Energy: -34.00
#     (159.46299743652344, 329.8182373046875, 244.18450927734375)
#     Interface Energy: -8.03
#     (172.37875366210938, 333.7409973144531, 213.31298828125)
#     Interface Energy: -8.80
#     (165.45864868164062, 345.8125915527344, 227.26675415039062)
#     Interface Energy: -187.63
# Chain GI:
#   Center of Mass (COM): (144.632080078125, 310.565673828125, 242.69131469726562)
#   Interfaces: ['DB', 'GH', 'GJ']
#   Interface Coordinates:
#     (141.90060424804688, 307.5894775390625, 243.4225311279297)
#     Interface Energy: -187.63
#     (152.09132385253906, 324.121337890625, 241.42601013183594)
#     Interface Energy: -8.03
#     (154.60540771484375, 301.74639892578125, 227.4442138671875)
#     Interface Energy: -20.90
# Chain GJ:
#   Center of Mass (COM): (161.3271026611328, 306.6469421386719, 205.30810546875)
#   Interfaces: ['CV', 'CX', 'GH', 'GI']
#   Interface Coordinates:
#     (154.00282287597656, 285.3085021972656, 199.2566680908203)
#     Interface Energy: -34.00
#     (162.61367797851562, 308.8799133300781, 202.2271728515625)
#     Interface Energy: -225.98
#     (173.78466796875, 326.023681640625, 207.7830047607422)
#     Interface Energy: -8.80
#     (156.4739990234375, 304.968994140625, 220.3601837158203)
#     Interface Energy: -20.90
# Chain GK:
#   Center of Mass (COM): (188.5381622314453, 229.08013916015625, 169.01901245117188)
#   Interfaces: ['DA', 'GL', 'GM', 'GX']
#   Interface Coordinates:
#     (177.9029998779297, 221.3741912841797, 181.33560180664062)
#     Interface Energy: -34.00
#     (188.0570068359375, 252.44775390625, 169.3247528076172)
#     Interface Energy: -8.03
#     (184.28199768066406, 221.51950073242188, 182.1490020751953)
#     Interface Energy: -8.80
#     (189.39105224609375, 228.9109344482422, 164.61083984375)
#     Interface Energy: -187.63
# Chain GL:
#   Center of Mass (COM): (169.36224365234375, 265.4488830566406, 177.94635009765625)
#   Interfaces: ['CV', 'GK', 'GM']
#   Interface Coordinates:
#     (166.59854125976562, 268.3725891113281, 178.76248168945312)
#     Interface Energy: -187.63
#     (178.9533233642578, 255.34266662597656, 171.09999084472656)
#     Interface Energy: -8.03
#     (167.08200073242188, 254.4412078857422, 194.7795867919922)
#     Interface Energy: -20.90
# Chain GM:
#   Center of Mass (COM): (162.96669006347656, 232.00552368164062, 201.01614379882812)
#   Interfaces: ['CY', 'DA', 'GK', 'GL']
#   Interface Coordinates:
#     (147.42132568359375, 240.04249572753906, 216.48716735839844)
#     Interface Energy: -34.00
#     (163.1569366455078, 227.99891662597656, 200.80506896972656)
#     Interface Energy: -225.98
#     (180.27000427246094, 220.46966552734375, 190.80433654785156)
#     Interface Energy: -8.80
#     (166.047607421875, 246.5216064453125, 195.29580688476562)
#     Interface Energy: -20.90
# Chain GN:
#   Center of Mass (COM): (142.86654663085938, 233.02186584472656, 288.5887145996094)
#   Interfaces: ['DD', 'GO', 'GP', 'GR']
#   Interface Coordinates:
#     (138.0395965576172, 250.1254119873047, 285.69903564453125)
#     Interface Energy: -34.00
#     (149.85125732421875, 221.73399353027344, 269.3487548828125)
#     Interface Energy: -8.03
#     (143.65225219726562, 248.739501953125, 288.5197448730469)
#     Interface Energy: -8.80
#     (141.30027770996094, 229.27651977539062, 290.51416015625)
#     Interface Energy: -187.63
# Chain GO:
#   Center of Mass (COM): (143.05526733398438, 227.9853973388672, 246.8194122314453)
#   Interfaces: ['CY', 'GN', 'GP']
#   Interface Coordinates:
#     (142.13088989257812, 228.037841796875, 242.8197479248047)
#     Interface Energy: -187.63
#     (144.26834106445312, 224.53599548339844, 261.9063415527344)
#     Interface Energy: -8.03
#     (146.22560119628906, 247.81240844726562, 249.3824005126953)
#     Interface Energy: -20.90
# Chain GP:
#   Center of Mass (COM): (139.08131408691406, 265.34735107421875, 263.54840087890625)
#   Interfaces: ['DB', 'DD', 'GN', 'GO']
#   Interface Coordinates:
#     (136.7241668701172, 278.6490173339844, 244.49298095703125)
#     Interface Energy: -34.00
#     (137.8916473388672, 267.12109375, 266.9502868652344)
#     Interface Energy: -225.98
#     (144.40933227539062, 257.5066833496094, 284.6886901855469)
#     Interface Energy: -8.80
#     (143.19961547851562, 252.50936889648438, 255.11282348632812)
#     Interface Energy: -20.90
# Chain GQ:
#   Center of Mass (COM): (166.92034912109375, 194.10177612304688, 307.7051086425781)
#   Interfaces: ['DG', 'GF', 'GR', 'GS']
#   Interface Coordinates:
#     (166.85580444335938, 203.49960327148438, 323.06280517578125)
#     Interface Energy: -34.00
#     (165.45863342285156, 190.18743896484375, 306.0533142089844)
#     Interface Energy: -187.63
#     (159.46299743652344, 206.1817626953125, 289.135498046875)
#     Interface Energy: -8.03
#     (172.37875366210938, 202.25900268554688, 320.00701904296875)
#     Interface Energy: -8.80
# Chain GR:
#   Center of Mass (COM): (144.632080078125, 225.43421936035156, 290.62896728515625)
#   Interfaces: ['GN', 'GQ', 'GS']
#   Interface Coordinates:
#     (141.90060424804688, 228.41049194335938, 289.8974609375)
#     Interface Energy: -187.63
#     (152.09132385253906, 211.878662109375, 291.8940124511719)
#     Interface Energy: -8.03
#     (154.60540771484375, 234.2535858154297, 305.87579345703125)
#     Interface Energy: -20.90
# Chain GS:
#   Center of Mass (COM): (161.3271026611328, 229.35301208496094, 328.0117492675781)
#   Interfaces: ['DE', 'DG', 'GQ', 'GR']
#   Interface Coordinates:
#     (154.00282287597656, 250.69151306152344, 334.0633544921875)
#     Interface Energy: -34.00
#     (162.61367797851562, 227.1200408935547, 331.0928649902344)
#     Interface Energy: -225.98
#     (173.78466796875, 209.97633361816406, 325.5370178222656)
#     Interface Energy: -8.80
#     (156.4739990234375, 231.031005859375, 312.9598083496094)
#     Interface Energy: -20.90
# Chain GT:
#   Center of Mass (COM): (183.91168212890625, 369.3907165527344, 263.2216796875)
#   Interfaces: ['DJ', 'FZ', 'GU', 'GV']
#   Interface Coordinates:
#     (194.44241333007812, 377.135986328125, 250.8404083251953)
#     Interface Energy: -34.00
#     (180.6935272216797, 370.46295166015625, 266.167724609375)
#     Interface Energy: -187.63
#     (172.32675170898438, 350.6317138671875, 255.45849609375)
#     Interface Energy: -8.03
#     (196.99923706054688, 373.5777282714844, 255.54949951171875)
#     Interface Energy: -8.80
# Chain GU:
#   Center of Mass (COM): (167.02398681640625, 346.797119140625, 232.00575256347656)
#   Interfaces: ['GH', 'GT', 'GV']
#   Interface Coordinates:
#     (165.36831665039062, 345.56109619140625, 228.4582061767578)
#     Interface Energy: -187.63
#     (169.50233459472656, 352.2929992675781, 246.31101989746094)
#     Interface Energy: -8.03
#     (185.44139099121094, 351.640380859375, 225.1457977294922)
#     Interface Energy: -20.90
# Chain GV:
#   Center of Mass (COM): (200.433349609375, 369.92181396484375, 225.63075256347656)
#   Interfaces: ['DH', 'DJ', 'GT', 'GU']
#   Interface Coordinates:
#     (204.1275177001953, 366.4116516113281, 202.83551025390625)
#     Interface Energy: -34.00
#     (202.32447814941406, 373.13336181640625, 227.12860107421875)
#     Interface Energy: -225.98
#     (203.2863311767578, 373.7586669921875, 248.3006591796875)
#     Interface Energy: -8.80
#     (189.4993896484375, 358.40521240234375, 226.4980010986328)
#     Interface Energy: -20.90
# Chain GW:
#   Center of Mass (COM): (229.58334350585938, 240.50759887695312, 143.6515655517578)
#   Interfaces: ['DM', 'GC', 'GX', 'GY']
#   Interface Coordinates:
#     (234.30581665039062, 223.364013671875, 146.47677612304688)
#     Interface Energy: -34.00
#     (228.7842559814453, 243.3494873046875, 140.26451110839844)
#     Interface Energy: -187.63
#     (210.53250122070312, 247.18649291992188, 155.4342498779297)
#     Interface Energy: -8.03
#     (237.62899780273438, 228.1632537841797, 149.1790008544922)
#     Interface Energy: -8.80
# Chain GX:
#   Center of Mass (COM): (193.33108520507812, 231.76876831054688, 163.13278198242188)
#   Interfaces: ['GK', 'GW', 'GY']
#   Interface Coordinates:
#     (189.8361358642578, 230.0283660888672, 164.40090942382812)
#     Interface Energy: -187.63
#     (204.18699645996094, 239.8283233642578, 155.5050048828125)
#     Interface Energy: -8.03
#     (206.29818725585938, 218.1060028076172, 170.54299926757812)
#     Interface Energy: -20.90
# Chain GY:
#   Center of Mass (COM): (224.31837463378906, 204.72500610351562, 163.09864807128906)
#   Interfaces: ['DK', 'DM', 'GW', 'GX']
#   Interface Coordinates:
#     (214.8245086669922, 186.89698791503906, 174.829833984375)
#     Interface Energy: -34.00
#     (227.58978271484375, 203.74656677246094, 160.9833984375)
#     Interface Energy: -225.98
#     (239.1473388671875, 220.2650146484375, 154.41600036621094)
#     Interface Energy: -8.80
#     (212.347412109375, 214.5637969970703, 166.6811981201172)
#     Interface Energy: -20.90

# %%
pdb_model.regularize_homologous_chains(dist_threshold_intra=3.5, 
                                       dist_threshold_inter=3.5, 
                                       angle_threshold=25.0, 
                                       show_coarse_grained_structure=False, 
                                       save_pymol_script=True, 
                                       standard_output=False)
# Out:
# Homologous chains identified using sequence alignment:
# {'EX': 'A', 'EW': 'A', 'AF': 'A', 'AS': 'A', 'EY': 'A', 'DI': 'A', 'GO': 'A', 'EB': 'A', 'GM': 'A', 'AT': 'A', 'FN': 'A', 'GH': 'A', 'FT': 'A', 'GN': 'A', 'FO': 'A', 'CA': 'A', 'FF': 'A', 'DK': 'A', 'BY': 'A', 'GW': 'A', 'GG': 'A', 'CS': 'A', 'GJ': 'A', 'DL': 'A', 'BV': 'A', 'EF': 'A', 'DM': 'A', 'EO': 'A', 'GF': 'A', 'GI': 'A', 'AH': 'A', 'EA': 'A', 'ER': 'A', 'AG': 'A', 'AM': 'A', 'CC': 'A', 'AN': 'A', 'ET': 'A', 'BF': 'A', 'EH': 'A', 'CX': 'A', 'GQ': 'A', 'DR': 'A', 'GV': 'A', 'GR': 'A', 'DT': 'A', 'FC': 'A', 'CF': 'A', 'EG': 'A', 'AC': 'A', 'GT': 'A', 'BR': 'A', 'BM': 'A', 'CE': 'A', 'CB': 'A', 'FL': 'A', 'BP': 'A', 'AY': 'A', 'DH': 'A', 'FQ': 'A', 'BS': 'A', 'DY': 'A', 'CY': 'A', 'GS': 'A', 'AP': 'A', 'DD': 'A', 'DV': 'A', 'GC': 'A', 'EJ': 'A', 'BA': 'A', 'FS': 'A', 'BE': 'A', 'FE': 'A', 'DG': 'A', 'EP': 'A', 'BB': 'A', 'BW': 'A', 'CM': 'A', 'DB': 'A', 'CW': 'A', 'EM': 'A', 'AW': 'A', 'EN': 'A', 'FK': 'A', 'EL': 'A', 'CK': 'A', 'CT': 'A', 'CO': 'A', 'DU': 'A', 'AR': 'A', 'GK': 'A', 'GA': 'A', 'DQ': 'A', 'GX': 'A', 'BD': 'A', 'FW': 'A', 'CZ': 'A', 'DP': 'A', 'FH': 'A', 'DZ': 'A', 'FM': 'A', 'AD': 'A', 'EI': 'A', 'BG': 'A', 'GL': 'A', 'AV': 'A', 'AI': 'A', 'AE': 'A', 'CI': 'A', 'DJ': 'A', 'FZ': 'A', 'AX': 'A', 'BJ': 'A', 'AJ': 'A', 'CL': 'A', 'FP': 'A', 'DE': 'A', 'AQ': 'A', 'BK': 'A', 'AL': 'A', 'FU': 'A', 'FY': 'A', 'EU': 'A', 'EV': 'A', 'FG': 'A', 'AZ': 'A', 'AO': 'A', 'DO': 'A', 'DS': 'A', 'CV': 'A', 'FA': 'A', 'GB': 'A', 'CJ': 'A', 'FJ': 'A', 'BL': 'A', 'CP': 'A', 'BN': 'A', 'FD': 'A', 'FB': 'A', 'CU': 'A', 'CN': 'A', 'EK': 'A', 'AB': 'A', 'CR': 'A', 'ED': 'A', 'DF': 'A', 'GD': 'A', 'EZ': 'A', 'DN': 'A', 'BO': 'A', 'GY': 'A', 'BT': 'A', 'CQ': 'A', 'DX': 'A', 'AU': 'A', 'FI': 'A', 'FR': 'A', 'DA': 'A', 'FV': 'A', 'EE': 'A', 'DC': 'A', 'GP': 'A', 'EQ': 'A', 'GE': 'A', 'BU': 'A', 'CH': 'A', 'CD': 'A', 'CG': 'A', 'AK': 'A', 'BX': 'A', 'BC': 'A', 'FX': 'A', 'GU': 'A', 'BZ': 'A', 'BQ': 'A', 'EC': 'A', 'DW': 'A', 'BI': 'A', 'BH': 'A', 'ES': 'A'}
# Homologous chain groups identified:
# [['AB', 'AC', 'AD', 'AE', 'AF', 'AG', 'AH', 'AI', 'AJ', 'AK', 'AL', 'AM', 'AN', 'AO', 'AP', 'AQ', 'AR', 'AS', 'AT', 'AU', 'AV', 'AW', 'AX', 'AY', 'AZ', 'BA', 'BB', 'BC', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BK', 'BL', 'BM', 'BN', 'BO', 'BP', 'BQ', 'BR', 'BS', 'BT', 'BU', 'BV', 'BW', 'BX', 'BY', 'BZ', 'CA', 'CB', 'CC', 'CD', 'CE', 'CF', 'CG', 'CH', 'CI', 'CJ', 'CK', 'CL', 'CM', 'CN', 'CO', 'CP', 'CQ', 'CR', 'CS', 'CT', 'CU', 'CV', 'CW', 'CX', 'CY', 'CZ', 'DA', 'DB', 'DC', 'DD', 'DE', 'DF', 'DG', 'DH', 'DI', 'DJ', 'DK', 'DL', 'DM', 'DN', 'DO', 'DP', 'DQ', 'DR', 'DS', 'DT', 'DU', 'DV', 'DW', 'DX', 'DY', 'DZ', 'EA', 'EB', 'EC', 'ED', 'EE', 'EF', 'EG', 'EH', 'EI', 'EJ', 'EK', 'EL', 'EM', 'EN', 'EO', 'EP', 'EQ', 'ER', 'ES', 'ET', 'EU', 'EV', 'EW', 'EX', 'EY', 'EZ', 'FA', 'FB', 'FC', 'FD', 'FE', 'FF', 'FG', 'FH', 'FI', 'FJ', 'FK', 'FL', 'FM', 'FN', 'FO', 'FP', 'FQ', 'FR', 'FS', 'FT', 'FU', 'FV', 'FW', 'FX', 'FY', 'FZ', 'GA', 'GB', 'GC', 'GD', 'GE', 'GF', 'GG', 'GH', 'GI', 'GJ', 'GK', 'GL', 'GM', 'GN', 'GO', 'GP', 'GQ', 'GR', 'GS', 'GT', 'GU', 'GV', 'GW', 'GX', 'GY']]
# Regularized coarse-grained structure saved to /Users/sikao/Documents/5lqp_dir/regularized_coarse_grained_structure.cif.
# PyMOL script saved to /Users/sikao/Documents/5lqp_dir/visualize_regularized_coarse_grained.pml.
# Model saved successfully to /Users/sikao/Documents/5lqp_dir/5lqp_model.json

# %%
if save_folder.startswith('~'):
    abs_save_folder = os.path.expanduser(save_folder)
abs_save_folder = os.path.abspath(abs_save_folder)

subprocess.run(["pymol", "-cq", f"{abs_save_folder}/visualize_regularized_coarse_grained.pml"], check=True)
display(Image(filename=f"{abs_save_folder}/comparison_regularized.png"))
# Out:
# PyMOL>load /Users/sikao/Documents/5lqp_dir/regularized_coarse_grained_structure.cif, coarse_grained
#  ExecutiveLoad-Detail: Detected mmCIF
#  CmdLoad: "/Users/sikao/Documents/5lqp_dir/regularized_coarse_grained_structure.cif" loaded as "coarse_grained".
# PyMOL>hide everything
# PyMOL>show spheres, name COM
# PyMOL>show spheres, name INT
# PyMOL>set sphere_scale, 1.0
#  Setting: sphere_scale set to 1.00000.
# PyMOL>color red, name COM
#  Executive: Colored 180 atoms.
# PyMOL>color blue, name INT
#  Executive: Colored 660 atoms.
# PyMOL>pseudoatom com_AB, pos=[246.071, 393.134, 231.682], color=red
#  ObjMol: created com_AB/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AB_1, pos=[265.311, 386.149, 220.394], color=blue
#  ObjMol: created int_AB_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line1, com_AB, int_AB_1
#  Executive: object "line1" created.
# PyMOL>set dash_width, 4, line1
#  Setting: dash_width set to 4.00000 in object "line1".
# PyMOL>set dash_gap, 0.5, line1
#  Setting: dash_gap set to 0.50000 in object "line1".
# PyMOL>pseudoatom int_AB_2, pos=[246.140, 392.348, 247.400], color=blue
#  ObjMol: created int_AB_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line2, com_AB, int_AB_2
#  Executive: object "line2" created.
# PyMOL>set dash_width, 4, line2
#  Setting: dash_width set to 4.00000 in object "line2".
# PyMOL>set dash_gap, 0.5, line2
#  Setting: dash_gap set to 0.50000 in object "line2".
# PyMOL>pseudoatom int_AB_3, pos=[244.146, 394.700, 227.937], color=blue
#  ObjMol: created int_AB_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line3, com_AB, int_AB_3
#  Executive: object "line3" created.
# PyMOL>set dash_width, 4, line3
#  Setting: dash_width set to 4.00000 in object "line3".
# PyMOL>set dash_gap, 0.5, line3
#  Setting: dash_gap set to 0.50000 in object "line3".
# PyMOL>pseudoatom int_AB_4, pos=[248.961, 397.960, 248.785], color=blue
#  ObjMol: created int_AB_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line4, com_AB, int_AB_4
#  Executive: object "line4" created.
# PyMOL>set dash_width, 4, line4
#  Setting: dash_width set to 4.00000 in object "line4".
# PyMOL>set dash_gap, 0.5, line4
#  Setting: dash_gap set to 0.50000 in object "line4".
# PyMOL>pseudoatom com_AC, pos=[287.851, 392.910, 226.637], color=red
#  ObjMol: created com_AC/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AC_1, pos=[272.764, 391.683, 223.193], color=blue
#  ObjMol: created int_AC_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line5, com_AC, int_AC_1
#  Executive: object "line5" created.
# PyMOL>set dash_width, 4, line5
#  Setting: dash_width set to 4.00000 in object "line5".
# PyMOL>set dash_gap, 0.5, line5
#  Setting: dash_gap set to 0.50000 in object "line5".
# PyMOL>pseudoatom int_AC_2, pos=[289.895, 386.979, 249.154], color=blue
#  ObjMol: created int_AC_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line6, com_AC, int_AC_2
#  Executive: object "line6" created.
# PyMOL>set dash_width, 4, line6
#  Setting: dash_width set to 4.00000 in object "line6".
# PyMOL>set dash_gap, 0.5, line6
#  Setting: dash_gap set to 0.50000 in object "line6".
# PyMOL>pseudoatom int_AC_3, pos=[291.851, 393.833, 226.696], color=blue
#  ObjMol: created int_AC_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line7, com_AC, int_AC_3
#  Executive: object "line7" created.
# PyMOL>set dash_width, 4, line7
#  Setting: dash_width set to 4.00000 in object "line7".
# PyMOL>set dash_gap, 0.5, line7
#  Setting: dash_gap set to 0.50000 in object "line7".
# PyMOL>pseudoatom com_AD, pos=[271.129, 396.934, 263.963], color=red
#  ObjMol: created com_AD/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AD_1, pos=[251.298, 387.731, 255.694], color=blue
#  ObjMol: created int_AD_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line8, com_AD, int_AD_1
#  Executive: object "line8" created.
# PyMOL>set dash_width, 4, line8
#  Setting: dash_width set to 4.00000 in object "line8".
# PyMOL>set dash_gap, 0.5, line8
#  Setting: dash_gap set to 0.50000 in object "line8".
# PyMOL>pseudoatom int_AD_2, pos=[282.269, 392.947, 253.913], color=blue
#  ObjMol: created int_AD_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line9, com_AD, int_AD_2
#  Executive: object "line9" created.
# PyMOL>set dash_width, 4, line9
#  Setting: dash_width set to 4.00000 in object "line9".
# PyMOL>set dash_gap, 0.5, line9
#  Setting: dash_gap set to 0.50000 in object "line9".
# PyMOL>pseudoatom int_AD_3, pos=[251.298, 387.731, 255.694], color=blue
#  ObjMol: created int_AD_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line10, com_AD, int_AD_3
#  Executive: object "line10" created.
# PyMOL>set dash_width, 4, line10
#  Setting: dash_width set to 4.00000 in object "line10".
# PyMOL>set dash_gap, 0.5, line10
#  Setting: dash_gap set to 0.50000 in object "line10".
# PyMOL>pseudoatom int_AD_4, pos=[267.726, 398.118, 265.738], color=blue
#  ObjMol: created int_AD_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line11, com_AD, int_AD_4
#  Executive: object "line11" created.
# PyMOL>set dash_width, 4, line11
#  Setting: dash_width set to 4.00000 in object "line11".
# PyMOL>set dash_gap, 0.5, line11
#  Setting: dash_gap set to 0.50000 in object "line11".
# PyMOL>pseudoatom com_AE, pos=[271.439, 183.912, 165.269], color=red
#  ObjMol: created com_AE/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AE_1, pos=[279.202, 172.327, 184.028], color=blue
#  ObjMol: created int_AE_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line12, com_AE, int_AE_1
#  Executive: object "line12" created.
# PyMOL>set dash_width, 4, line12
#  Setting: dash_width set to 4.00000 in object "line12".
# PyMOL>set dash_gap, 0.5, line12
#  Setting: dash_gap set to 0.50000 in object "line12".
# PyMOL>pseudoatom int_AE_2, pos=[281.817, 195.121, 162.506], color=blue
#  ObjMol: created int_AE_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line13, com_AE, int_AE_2
#  Executive: object "line13" created.
# PyMOL>set dash_width, 4, line13
#  Setting: dash_width set to 4.00000 in object "line13".
# PyMOL>set dash_gap, 0.5, line13
#  Setting: dash_gap set to 0.50000 in object "line13".
# PyMOL>pseudoatom int_AE_3, pos=[268.492, 180.694, 164.197], color=blue
#  ObjMol: created int_AE_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line14, com_AE, int_AE_3
#  Executive: object "line14" created.
# PyMOL>set dash_width, 4, line14
#  Setting: dash_width set to 4.00000 in object "line14".
# PyMOL>set dash_gap, 0.5, line14
#  Setting: dash_gap set to 0.50000 in object "line14".
# PyMOL>pseudoatom int_AE_4, pos=[281.817, 195.121, 162.506], color=blue
#  ObjMol: created int_AE_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line15, com_AE, int_AE_4
#  Executive: object "line15" created.
# PyMOL>set dash_width, 4, line15
#  Setting: dash_width set to 4.00000 in object "line15".
# PyMOL>set dash_gap, 0.5, line15
#  Setting: dash_gap set to 0.50000 in object "line15".
# PyMOL>pseudoatom com_AF, pos=[302.648, 167.031, 187.898], color=red
#  ObjMol: created com_AF/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AF_1, pos=[288.342, 169.509, 182.402], color=blue
#  ObjMol: created int_AF_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line16, com_AF, int_AF_1
#  Executive: object "line16" created.
# PyMOL>set dash_width, 4, line16
#  Setting: dash_width set to 4.00000 in object "line16".
# PyMOL>set dash_gap, 0.5, line16
#  Setting: dash_gap set to 0.50000 in object "line16".
# PyMOL>pseudoatom int_AF_2, pos=[313.717, 187.587, 186.754], color=blue
#  ObjMol: created int_AF_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line17, com_AF, int_AF_2
#  Executive: object "line17" created.
# PyMOL>set dash_width, 4, line17
#  Setting: dash_width set to 4.00000 in object "line17".
# PyMOL>set dash_gap, 0.5, line17
#  Setting: dash_gap set to 0.50000 in object "line17".
# PyMOL>pseudoatom int_AF_3, pos=[306.198, 165.385, 189.137], color=blue
#  ObjMol: created int_AF_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line18, com_AF, int_AF_3
#  Executive: object "line18" created.
# PyMOL>set dash_width, 4, line18
#  Setting: dash_width set to 4.00000 in object "line18".
# PyMOL>set dash_gap, 0.5, line18
#  Setting: dash_gap set to 0.50000 in object "line18".
# PyMOL>pseudoatom com_AG, pos=[309.026, 200.384, 164.748], color=red
#  ObjMol: created com_AG/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AG_1, pos=[285.997, 204.385, 164.791], color=blue
#  ObjMol: created int_AG_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line19, com_AG, int_AG_1
#  Executive: object "line19" created.
# PyMOL>set dash_width, 4, line19
#  Setting: dash_width set to 4.00000 in object "line19".
# PyMOL>set dash_gap, 0.5, line19
#  Setting: dash_gap set to 0.50000 in object "line19".
# PyMOL>pseudoatom int_AG_2, pos=[311.777, 190.816, 176.660], color=blue
#  ObjMol: created int_AG_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line20, com_AG, int_AG_2
#  Executive: object "line20" created.
# PyMOL>set dash_width, 4, line20
#  Setting: dash_width set to 4.00000 in object "line20".
# PyMOL>set dash_gap, 0.5, line20
#  Setting: dash_gap set to 0.50000 in object "line20".
# PyMOL>pseudoatom int_AG_3, pos=[285.997, 204.385, 164.791], color=blue
#  ObjMol: created int_AG_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line21, com_AG, int_AG_3
#  Executive: object "line21" created.
# PyMOL>set dash_width, 4, line21
#  Setting: dash_width set to 4.00000 in object "line21".
# PyMOL>set dash_gap, 0.5, line21
#  Setting: dash_gap set to 0.50000 in object "line21".
# PyMOL>pseudoatom int_AG_4, pos=[307.529, 202.275, 161.536], color=blue
#  ObjMol: created int_AG_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line22, com_AG, int_AG_4
#  Executive: object "line22" created.
# PyMOL>set dash_width, 4, line22
#  Setting: dash_width set to 4.00000 in object "line22".
# PyMOL>set dash_gap, 0.5, line22
#  Setting: dash_gap set to 0.50000 in object "line22".
# PyMOL>pseudoatom com_AH, pos=[194.102, 226.955, 367.740], color=red
#  ObjMol: created com_AH/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AH_1, pos=[206.182, 245.525, 375.197], color=blue
#  ObjMol: created int_AH_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line23, com_AH, int_AH_1
#  Executive: object "line23" created.
# PyMOL>set dash_width, 4, line23
#  Setting: dash_width set to 4.00000 in object "line23".
# PyMOL>set dash_gap, 0.5, line23
#  Setting: dash_gap set to 0.50000 in object "line23".
# PyMOL>pseudoatom int_AH_2, pos=[204.580, 215.908, 364.714], color=blue
#  ObjMol: created int_AH_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line24, com_AH, int_AH_2
#  Executive: object "line24" created.
# PyMOL>set dash_width, 4, line24
#  Setting: dash_width set to 4.00000 in object "line24".
# PyMOL>set dash_gap, 0.5, line24
#  Setting: dash_gap set to 0.50000 in object "line24".
# PyMOL>pseudoatom int_AH_3, pos=[190.188, 228.607, 369.201], color=blue
#  ObjMol: created int_AH_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line25, com_AH, int_AH_3
#  Executive: object "line25" created.
# PyMOL>set dash_width, 4, line25
#  Setting: dash_width set to 4.00000 in object "line25".
# PyMOL>set dash_gap, 0.5, line25
#  Setting: dash_gap set to 0.50000 in object "line25".
# PyMOL>pseudoatom int_AH_4, pos=[204.580, 215.908, 364.714], color=blue
#  ObjMol: created int_AH_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line26, com_AH, int_AH_4
#  Executive: object "line26" created.
# PyMOL>set dash_width, 4, line26
#  Setting: dash_width set to 4.00000 in object "line26".
# PyMOL>set dash_gap, 0.5, line26
#  Setting: dash_gap set to 0.50000 in object "line26".
# PyMOL>pseudoatom com_AI, pos=[225.449, 244.058, 390.009], color=red
#  ObjMol: created com_AI/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AI_1, pos=[211.907, 242.785, 382.526], color=blue
#  ObjMol: created int_AI_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line27, com_AI, int_AI_1
#  Executive: object "line27" created.
# PyMOL>set dash_width, 4, line27
#  Setting: dash_width set to 4.00000 in object "line27".
# PyMOL>set dash_gap, 0.5, line27
#  Setting: dash_gap set to 0.50000 in object "line27".
# PyMOL>pseudoatom int_AI_2, pos=[240.195, 229.398, 379.331], color=blue
#  ObjMol: created int_AI_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line28, com_AI, int_AI_2
#  Executive: object "line28" created.
# PyMOL>set dash_width, 4, line28
#  Setting: dash_width set to 4.00000 in object "line28".
# PyMOL>set dash_gap, 0.5, line28
#  Setting: dash_gap set to 0.50000 in object "line28".
# PyMOL>pseudoatom int_AI_3, pos=[228.427, 244.790, 392.738], color=blue
#  ObjMol: created int_AI_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line29, com_AI, int_AI_3
#  Executive: object "line29" created.
# PyMOL>set dash_width, 4, line29
#  Setting: dash_width set to 4.00000 in object "line29".
# PyMOL>set dash_gap, 0.5, line29
#  Setting: dash_gap set to 0.50000 in object "line29".
# PyMOL>pseudoatom com_AJ, pos=[229.340, 206.682, 373.368], color=red
#  ObjMol: created com_AJ/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AJ_1, pos=[212.006, 211.845, 358.562], color=blue
#  ObjMol: created int_AJ_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line30, com_AJ, int_AJ_1
#  Executive: object "line30" created.
# PyMOL>set dash_width, 4, line30
#  Setting: dash_width set to 4.00000 in object "line30".
# PyMOL>set dash_gap, 0.5, line30
#  Setting: dash_gap set to 0.50000 in object "line30".
# PyMOL>pseudoatom int_AJ_2, pos=[234.560, 220.248, 378.817], color=blue
#  ObjMol: created int_AJ_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line31, com_AJ, int_AJ_2
#  Executive: object "line31" created.
# PyMOL>set dash_width, 4, line31
#  Setting: dash_width set to 4.00000 in object "line31".
# PyMOL>set dash_gap, 0.5, line31
#  Setting: dash_gap set to 0.50000 in object "line31".
# PyMOL>pseudoatom int_AJ_3, pos=[212.006, 211.845, 358.562], color=blue
#  ObjMol: created int_AJ_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line32, com_AJ, int_AJ_3
#  Executive: object "line32" created.
# PyMOL>set dash_width, 4, line32
#  Setting: dash_width set to 4.00000 in object "line32".
# PyMOL>set dash_gap, 0.5, line32
#  Setting: dash_gap set to 0.50000 in object "line32".
# PyMOL>pseudoatom int_AJ_4, pos=[227.109, 203.602, 372.076], color=blue
#  ObjMol: created int_AJ_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line33, com_AJ, int_AJ_4
#  Executive: object "line33" created.
# PyMOL>set dash_width, 4, line33
#  Setting: dash_width set to 4.00000 in object "line33".
# PyMOL>set dash_gap, 0.5, line33
#  Setting: dash_gap set to 0.50000 in object "line33".
# PyMOL>pseudoatom com_AK, pos=[246.071, 142.866, 301.638], color=red
#  ObjMol: created com_AK/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AK_1, pos=[265.311, 149.851, 312.926], color=blue
#  ObjMol: created int_AK_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line34, com_AK, int_AK_1
#  Executive: object "line34" created.
# PyMOL>set dash_width, 4, line34
#  Setting: dash_width set to 4.00000 in object "line34".
# PyMOL>set dash_gap, 0.5, line34
#  Setting: dash_gap set to 0.50000 in object "line34".
# PyMOL>pseudoatom int_AK_2, pos=[249.622, 143.029, 286.527], color=blue
#  ObjMol: created int_AK_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line35, com_AK, int_AK_2
#  Executive: object "line35" created.
# PyMOL>set dash_width, 4, line35
#  Setting: dash_width set to 4.00000 in object "line35".
# PyMOL>set dash_gap, 0.5, line35
#  Setting: dash_gap set to 0.50000 in object "line35".
# PyMOL>pseudoatom int_AK_3, pos=[244.146, 141.300, 305.383], color=blue
#  ObjMol: created int_AK_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line36, com_AK, int_AK_3
#  Executive: object "line36" created.
# PyMOL>set dash_width, 4, line36
#  Setting: dash_width set to 4.00000 in object "line36".
# PyMOL>set dash_gap, 0.5, line36
#  Setting: dash_gap set to 0.50000 in object "line36".
# PyMOL>pseudoatom int_AK_4, pos=[249.622, 143.029, 286.527], color=blue
#  ObjMol: created int_AK_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line37, com_AK, int_AK_4
#  Executive: object "line37" created.
# PyMOL>set dash_width, 4, line37
#  Setting: dash_width set to 4.00000 in object "line37".
# PyMOL>set dash_gap, 0.5, line37
#  Setting: dash_gap set to 0.50000 in object "line37".
# PyMOL>pseudoatom com_AL, pos=[287.851, 143.089, 306.683], color=red
#  ObjMol: created com_AL/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AL_1, pos=[272.764, 144.303, 310.132], color=blue
#  ObjMol: created int_AL_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line38, com_AL, int_AL_1
#  Executive: object "line38" created.
# PyMOL>set dash_width, 4, line38
#  Setting: dash_width set to 4.00000 in object "line38".
# PyMOL>set dash_gap, 0.5, line38
#  Setting: dash_gap set to 0.50000 in object "line38".
# PyMOL>pseudoatom int_AL_2, pos=[289.882, 149.021, 284.165], color=blue
#  ObjMol: created int_AL_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line39, com_AL, int_AL_2
#  Executive: object "line39" created.
# PyMOL>set dash_width, 4, line39
#  Setting: dash_width set to 4.00000 in object "line39".
# PyMOL>set dash_gap, 0.5, line39
#  Setting: dash_gap set to 0.50000 in object "line39".
# PyMOL>pseudoatom int_AL_3, pos=[291.851, 142.171, 306.622], color=blue
#  ObjMol: created int_AL_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line40, com_AL, int_AL_3
#  Executive: object "line40" created.
# PyMOL>set dash_width, 4, line40
#  Setting: dash_width set to 4.00000 in object "line40".
# PyMOL>set dash_gap, 0.5, line40
#  Setting: dash_gap set to 0.50000 in object "line40".
# PyMOL>pseudoatom com_AM, pos=[271.130, 139.065, 269.357], color=red
#  ObjMol: created com_AM/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AM_1, pos=[251.283, 148.217, 277.648], color=blue
#  ObjMol: created int_AM_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line41, com_AM, int_AM_1
#  Executive: object "line41" created.
# PyMOL>set dash_width, 4, line41
#  Setting: dash_width set to 4.00000 in object "line41".
# PyMOL>set dash_gap, 0.5, line41
#  Setting: dash_gap set to 0.50000 in object "line41".
# PyMOL>pseudoatom int_AM_2, pos=[282.267, 143.068, 279.403], color=blue
#  ObjMol: created int_AM_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line42, com_AM, int_AM_2
#  Executive: object "line42" created.
# PyMOL>set dash_width, 4, line42
#  Setting: dash_width set to 4.00000 in object "line42".
# PyMOL>set dash_gap, 0.5, line42
#  Setting: dash_gap set to 0.50000 in object "line42".
# PyMOL>pseudoatom int_AM_3, pos=[251.283, 148.217, 277.648], color=blue
#  ObjMol: created int_AM_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line43, com_AM, int_AM_3
#  Executive: object "line43" created.
# PyMOL>set dash_width, 4, line43
#  Setting: dash_width set to 4.00000 in object "line43".
# PyMOL>set dash_gap, 0.5, line43
#  Setting: dash_gap set to 0.50000 in object "line43".
# PyMOL>pseudoatom int_AM_4, pos=[267.728, 137.876, 267.583], color=blue
#  ObjMol: created int_AM_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line44, com_AM, int_AM_4
#  Executive: object "line44" created.
# PyMOL>set dash_width, 4, line44
#  Setting: dash_width set to 4.00000 in object "line44".
# PyMOL>set dash_gap, 0.5, line44
#  Setting: dash_gap set to 0.50000 in object "line44".
# PyMOL>pseudoatom com_AN, pos=[229.080, 365.641, 346.122], color=red
#  ObjMol: created com_AN/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AN_1, pos=[252.448, 365.335, 346.603], color=blue
#  ObjMol: created int_AN_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line45, com_AN, int_AN_1
#  Executive: object "line45" created.
# PyMOL>set dash_width, 4, line45
#  Setting: dash_width set to 4.00000 in object "line45".
# PyMOL>set dash_gap, 0.5, line45
#  Setting: dash_gap set to 0.50000 in object "line45".
# PyMOL>pseudoatom int_AN_2, pos=[224.447, 352.237, 352.436], color=blue
#  ObjMol: created int_AN_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line46, com_AN, int_AN_2
#  Executive: object "line46" created.
# PyMOL>set dash_width, 4, line46
#  Setting: dash_width set to 4.00000 in object "line46".
# PyMOL>set dash_gap, 0.5, line46
#  Setting: dash_gap set to 0.50000 in object "line46".
# PyMOL>pseudoatom int_AN_3, pos=[228.911, 370.049, 345.269], color=blue
#  ObjMol: created int_AN_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line47, com_AN, int_AN_3
#  Executive: object "line47" created.
# PyMOL>set dash_width, 4, line47
#  Setting: dash_width set to 4.00000 in object "line47".
# PyMOL>set dash_gap, 0.5, line47
#  Setting: dash_gap set to 0.50000 in object "line47".
# PyMOL>pseudoatom int_AN_4, pos=[224.447, 352.237, 352.436], color=blue
#  ObjMol: created int_AN_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line48, com_AN, int_AN_4
#  Executive: object "line48" created.
# PyMOL>set dash_width, 4, line48
#  Setting: dash_width set to 4.00000 in object "line48".
# PyMOL>set dash_gap, 0.5, line48
#  Setting: dash_gap set to 0.50000 in object "line48".
# PyMOL>pseudoatom com_AO, pos=[265.472, 356.700, 365.272], color=red
#  ObjMol: created com_AO/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AO_1, pos=[255.367, 363.535, 355.672], color=blue
#  ObjMol: created int_AO_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line49, com_AO, int_AO_1
#  Executive: object "line49" created.
# PyMOL>set dash_width, 4, line49
#  Setting: dash_width set to 4.00000 in object "line49".
# PyMOL>set dash_gap, 0.5, line49
#  Setting: dash_gap set to 0.50000 in object "line49".
# PyMOL>pseudoatom int_AO_2, pos=[257.700, 334.886, 368.454], color=blue
#  ObjMol: created int_AO_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line50, com_AO, int_AO_2
#  Executive: object "line50" created.
# PyMOL>set dash_width, 4, line50
#  Setting: dash_width set to 4.00000 in object "line50".
# PyMOL>set dash_gap, 0.5, line50
#  Setting: dash_gap set to 0.50000 in object "line50".
# PyMOL>pseudoatom int_AO_3, pos=[268.393, 355.877, 368.037], color=blue
#  ObjMol: created int_AO_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line51, com_AO, int_AO_3
#  Executive: object "line51" created.
# PyMOL>set dash_width, 4, line51
#  Setting: dash_width set to 4.00000 in object "line51".
# PyMOL>set dash_gap, 0.5, line51
#  Setting: dash_gap set to 0.50000 in object "line51".
# PyMOL>pseudoatom com_AP, pos=[232.037, 333.682, 371.702], color=red
#  ObjMol: created com_AP/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AP_1, pos=[222.955, 341.947, 351.812], color=blue
#  ObjMol: created int_AP_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line52, com_AP, int_AP_1
#  Executive: object "line52" created.
# PyMOL>set dash_width, 4, line52
#  Setting: dash_width set to 4.00000 in object "line52".
# PyMOL>set dash_gap, 0.5, line52
#  Setting: dash_gap set to 0.50000 in object "line52".
# PyMOL>pseudoatom int_AP_2, pos=[247.308, 336.366, 370.928], color=blue
#  ObjMol: created int_AP_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line53, com_AP, int_AP_2
#  Executive: object "line53" created.
# PyMOL>set dash_width, 4, line53
#  Setting: dash_width set to 4.00000 in object "line53".
# PyMOL>set dash_gap, 0.5, line53
#  Setting: dash_gap set to 0.50000 in object "line53".
# PyMOL>pseudoatom int_AP_3, pos=[222.955, 341.947, 351.812], color=blue
#  ObjMol: created int_AP_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line54, com_AP, int_AP_3
#  Executive: object "line54" created.
# PyMOL>set dash_width, 4, line54
#  Setting: dash_width set to 4.00000 in object "line54".
# PyMOL>set dash_gap, 0.5, line54
#  Setting: dash_gap set to 0.50000 in object "line54".
# PyMOL>pseudoatom int_AP_4, pos=[228.031, 333.893, 371.511], color=blue
#  ObjMol: created int_AP_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line55, com_AP, int_AP_4
#  Executive: object "line55" created.
# PyMOL>set dash_width, 4, line55
#  Setting: dash_width set to 4.00000 in object "line55".
# PyMOL>set dash_gap, 0.5, line55
#  Setting: dash_gap set to 0.50000 in object "line55".
# PyMOL>pseudoatom com_AQ, pos=[306.417, 295.492, 143.651], color=red
#  ObjMol: created com_AQ/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AQ_1, pos=[325.468, 288.814, 155.434], color=blue
#  ObjMol: created int_AQ_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line56, com_AQ, int_AQ_1
#  Executive: object "line56" created.
# PyMOL>set dash_width, 4, line56
#  Setting: dash_width set to 4.00000 in object "line56".
# PyMOL>set dash_gap, 0.5, line56
#  Setting: dash_gap set to 0.50000 in object "line56".
# PyMOL>pseudoatom int_AQ_2, pos=[301.684, 308.734, 150.228], color=blue
#  ObjMol: created int_AQ_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line57, com_AQ, int_AQ_2
#  Executive: object "line57" created.
# PyMOL>set dash_width, 4, line57
#  Setting: dash_width set to 4.00000 in object "line57".
# PyMOL>set dash_gap, 0.5, line57
#  Setting: dash_gap set to 0.50000 in object "line57".
# PyMOL>pseudoatom int_AQ_3, pos=[307.216, 292.651, 140.265], color=blue
#  ObjMol: created int_AQ_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line58, com_AQ, int_AQ_3
#  Executive: object "line58" created.
# PyMOL>set dash_width, 4, line58
#  Setting: dash_width set to 4.00000 in object "line58".
# PyMOL>set dash_gap, 0.5, line58
#  Setting: dash_gap set to 0.50000 in object "line58".
# PyMOL>pseudoatom int_AQ_4, pos=[301.684, 308.734, 150.228], color=blue
#  ObjMol: created int_AQ_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line59, com_AQ, int_AQ_4
#  Executive: object "line59" created.
# PyMOL>set dash_width, 4, line59
#  Setting: dash_width set to 4.00000 in object "line59".
# PyMOL>set dash_gap, 0.5, line59
#  Setting: dash_gap set to 0.50000 in object "line59".
# PyMOL>pseudoatom com_AR, pos=[342.671, 304.210, 163.163], color=red
#  ObjMol: created com_AR/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AR_1, pos=[331.810, 296.146, 155.547], color=blue
#  ObjMol: created int_AR_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line60, com_AR, int_AR_1
#  Executive: object "line60" created.
# PyMOL>set dash_width, 4, line60
#  Setting: dash_width set to 4.00000 in object "line60".
# PyMOL>set dash_gap, 0.5, line60
#  Setting: dash_gap set to 0.50000 in object "line60".
# PyMOL>pseudoatom int_AR_2, pos=[331.230, 320.099, 175.931], color=blue
#  ObjMol: created int_AR_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line61, com_AR, int_AR_2
#  Executive: object "line61" created.
# PyMOL>set dash_width, 4, line61
#  Setting: dash_width set to 4.00000 in object "line61".
# PyMOL>set dash_gap, 0.5, line61
#  Setting: dash_gap set to 0.50000 in object "line61".
# PyMOL>pseudoatom int_AR_3, pos=[346.161, 305.956, 164.436], color=blue
#  ObjMol: created int_AR_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line62, com_AR, int_AR_3
#  Executive: object "line62" created.
# PyMOL>set dash_width, 4, line62
#  Setting: dash_width set to 4.00000 in object "line62".
# PyMOL>set dash_gap, 0.5, line62
#  Setting: dash_gap set to 0.50000 in object "line62".
# PyMOL>pseudoatom com_AS, pos=[311.724, 331.252, 163.081], color=red
#  ObjMol: created com_AS/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AS_1, pos=[296.985, 313.836, 158.000], color=blue
#  ObjMol: created int_AS_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line63, com_AS, int_AS_1
#  Executive: object "line63" created.
# PyMOL>set dash_width, 4, line63
#  Setting: dash_width set to 4.00000 in object "line63".
# PyMOL>set dash_gap, 0.5, line63
#  Setting: dash_gap set to 0.50000 in object "line63".
# PyMOL>pseudoatom int_AS_2, pos=[324.520, 324.565, 168.784], color=blue
#  ObjMol: created int_AS_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line64, com_AS, int_AS_2
#  Executive: object "line64" created.
# PyMOL>set dash_width, 4, line64
#  Setting: dash_width set to 4.00000 in object "line64".
# PyMOL>set dash_gap, 0.5, line64
#  Setting: dash_gap set to 0.50000 in object "line64".
# PyMOL>pseudoatom int_AS_3, pos=[296.985, 313.836, 158.000], color=blue
#  ObjMol: created int_AS_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line65, com_AS, int_AS_3
#  Executive: object "line65" created.
# PyMOL>set dash_width, 4, line65
#  Setting: dash_width set to 4.00000 in object "line65".
# PyMOL>set dash_gap, 0.5, line65
#  Setting: dash_gap set to 0.50000 in object "line65".
# PyMOL>pseudoatom int_AS_4, pos=[308.452, 332.231, 160.966], color=blue
#  ObjMol: created int_AS_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line66, com_AS, int_AS_4
#  Executive: object "line66" created.
# PyMOL>set dash_width, 4, line66
#  Setting: dash_width set to 4.00000 in object "line66".
# PyMOL>set dash_gap, 0.5, line66
#  Setting: dash_gap set to 0.50000 in object "line66".
# PyMOL>pseudoatom com_AT, pos=[369.080, 341.898, 307.705], color=red
#  ObjMol: created com_AT/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AT_1, pos=[376.537, 329.818, 289.135], color=blue
#  ObjMol: created int_AT_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line67, com_AT, int_AT_1
#  Executive: object "line67" created.
# PyMOL>set dash_width, 4, line67
#  Setting: dash_width set to 4.00000 in object "line67".
# PyMOL>set dash_gap, 0.5, line67
#  Setting: dash_gap set to 0.50000 in object "line67".
# PyMOL>pseudoatom int_AT_2, pos=[366.054, 331.420, 318.752], color=blue
#  ObjMol: created int_AT_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line68, com_AT, int_AT_2
#  Executive: object "line68" created.
# PyMOL>set dash_width, 4, line68
#  Setting: dash_width set to 4.00000 in object "line68".
# PyMOL>set dash_gap, 0.5, line68
#  Setting: dash_gap set to 0.50000 in object "line68".
# PyMOL>pseudoatom int_AT_3, pos=[370.541, 345.812, 306.053], color=blue
#  ObjMol: created int_AT_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line69, com_AT, int_AT_3
#  Executive: object "line69" created.
# PyMOL>set dash_width, 4, line69
#  Setting: dash_width set to 4.00000 in object "line69".
# PyMOL>set dash_gap, 0.5, line69
#  Setting: dash_gap set to 0.50000 in object "line69".
# PyMOL>pseudoatom int_AT_4, pos=[366.054, 331.420, 318.752], color=blue
#  ObjMol: created int_AT_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line70, com_AT, int_AT_4
#  Executive: object "line70" created.
# PyMOL>set dash_width, 4, line70
#  Setting: dash_width set to 4.00000 in object "line70".
# PyMOL>set dash_gap, 0.5, line70
#  Setting: dash_gap set to 0.50000 in object "line70".
# PyMOL>pseudoatom com_AU, pos=[391.349, 310.551, 290.602], color=red
#  ObjMol: created com_AU/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AU_1, pos=[383.866, 324.093, 291.876], color=blue
#  ObjMol: created int_AU_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line71, com_AU, int_AU_1
#  Executive: object "line71" created.
# PyMOL>set dash_width, 4, line71
#  Setting: dash_width set to 4.00000 in object "line71".
# PyMOL>set dash_gap, 0.5, line71
#  Setting: dash_gap set to 0.50000 in object "line71".
# PyMOL>pseudoatom int_AU_2, pos=[380.671, 295.805, 305.262], color=blue
#  ObjMol: created int_AU_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line72, com_AU, int_AU_2
#  Executive: object "line72" created.
# PyMOL>set dash_width, 4, line72
#  Setting: dash_width set to 4.00000 in object "line72".
# PyMOL>set dash_gap, 0.5, line72
#  Setting: dash_gap set to 0.50000 in object "line72".
# PyMOL>pseudoatom int_AU_3, pos=[394.078, 307.573, 289.870], color=blue
#  ObjMol: created int_AU_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line73, com_AU, int_AU_3
#  Executive: object "line73" created.
# PyMOL>set dash_width, 4, line73
#  Setting: dash_width set to 4.00000 in object "line73".
# PyMOL>set dash_gap, 0.5, line73
#  Setting: dash_gap set to 0.50000 in object "line73".
# PyMOL>pseudoatom com_AV, pos=[374.708, 306.660, 327.978], color=red
#  ObjMol: created com_AV/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AV_1, pos=[359.896, 323.989, 322.813], color=blue
#  ObjMol: created int_AV_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line74, com_AV, int_AV_1
#  Executive: object "line74" created.
# PyMOL>set dash_width, 4, line74
#  Setting: dash_width set to 4.00000 in object "line74".
# PyMOL>set dash_gap, 0.5, line74
#  Setting: dash_gap set to 0.50000 in object "line74".
# PyMOL>pseudoatom int_AV_2, pos=[380.159, 301.440, 314.412], color=blue
#  ObjMol: created int_AV_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line75, com_AV, int_AV_2
#  Executive: object "line75" created.
# PyMOL>set dash_width, 4, line75
#  Setting: dash_width set to 4.00000 in object "line75".
# PyMOL>set dash_gap, 0.5, line75
#  Setting: dash_gap set to 0.50000 in object "line75".
# PyMOL>pseudoatom int_AV_3, pos=[359.896, 323.989, 322.813], color=blue
#  ObjMol: created int_AV_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line76, com_AV, int_AV_3
#  Executive: object "line76" created.
# PyMOL>set dash_width, 4, line76
#  Setting: dash_width set to 4.00000 in object "line76".
# PyMOL>set dash_gap, 0.5, line76
#  Setting: dash_gap set to 0.50000 in object "line76".
# PyMOL>pseudoatom int_AV_4, pos=[373.415, 308.891, 331.057], color=blue
#  ObjMol: created int_AV_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line77, com_AV, int_AV_4
#  Executive: object "line77" created.
# PyMOL>set dash_width, 4, line77
#  Setting: dash_width set to 4.00000 in object "line77".
# PyMOL>set dash_gap, 0.5, line77
#  Setting: dash_gap set to 0.50000 in object "line77".
# PyMOL>pseudoatom com_AW, pos=[393.134, 233.022, 244.731], color=red
#  ObjMol: created com_AW/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AW_1, pos=[386.149, 221.734, 263.971], color=blue
#  ObjMol: created int_AW_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line78, com_AW, int_AW_1
#  Executive: object "line78" created.
# PyMOL>set dash_width, 4, line78
#  Setting: dash_width set to 4.00000 in object "line78".
# PyMOL>set dash_gap, 0.5, line78
#  Setting: dash_gap set to 0.50000 in object "line78".
# PyMOL>pseudoatom int_AW_2, pos=[392.971, 248.133, 248.282], color=blue
#  ObjMol: created int_AW_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line79, com_AW, int_AW_2
#  Executive: object "line79" created.
# PyMOL>set dash_width, 4, line79
#  Setting: dash_width set to 4.00000 in object "line79".
# PyMOL>set dash_gap, 0.5, line79
#  Setting: dash_gap set to 0.50000 in object "line79".
# PyMOL>pseudoatom int_AW_3, pos=[394.700, 229.277, 242.806], color=blue
#  ObjMol: created int_AW_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line80, com_AW, int_AW_3
#  Executive: object "line80" created.
# PyMOL>set dash_width, 4, line80
#  Setting: dash_width set to 4.00000 in object "line80".
# PyMOL>set dash_gap, 0.5, line80
#  Setting: dash_gap set to 0.50000 in object "line80".
# PyMOL>pseudoatom int_AW_4, pos=[392.971, 248.133, 248.282], color=blue
#  ObjMol: created int_AW_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line81, com_AW, int_AW_4
#  Executive: object "line81" created.
# PyMOL>set dash_width, 4, line81
#  Setting: dash_width set to 4.00000 in object "line81".
# PyMOL>set dash_gap, 0.5, line81
#  Setting: dash_gap set to 0.50000 in object "line81".
# PyMOL>pseudoatom com_AX, pos=[392.911, 227.977, 286.511], color=red
#  ObjMol: created com_AX/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AX_1, pos=[391.666, 224.551, 271.421], color=blue
#  ObjMol: created int_AX_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line82, com_AX, int_AX_1
#  Executive: object "line82" created.
# PyMOL>set dash_width, 4, line82
#  Setting: dash_width set to 4.00000 in object "line82".
# PyMOL>set dash_gap, 0.5, line82
#  Setting: dash_gap set to 0.50000 in object "line82".
# PyMOL>pseudoatom int_AX_2, pos=[387.057, 250.512, 288.579], color=blue
#  ObjMol: created int_AX_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line83, com_AX, int_AX_2
#  Executive: object "line83" created.
# PyMOL>set dash_width, 4, line83
#  Setting: dash_width set to 4.00000 in object "line83".
# PyMOL>set dash_gap, 0.5, line83
#  Setting: dash_gap set to 0.50000 in object "line83".
# PyMOL>pseudoatom int_AX_3, pos=[393.836, 228.030, 290.510], color=blue
#  ObjMol: created int_AX_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line84, com_AX, int_AX_3
#  Executive: object "line84" created.
# PyMOL>set dash_width, 4, line84
#  Setting: dash_width set to 4.00000 in object "line84".
# PyMOL>set dash_gap, 0.5, line84
#  Setting: dash_gap set to 0.50000 in object "line84".
# PyMOL>pseudoatom com_AY, pos=[396.934, 265.303, 269.789], color=red
#  ObjMol: created com_AY/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AY_1, pos=[387.724, 257.036, 249.960], color=blue
#  ObjMol: created int_AY_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line85, com_AY, int_AY_1
#  Executive: object "line85" created.
# PyMOL>set dash_width, 4, line85
#  Setting: dash_width set to 4.00000 in object "line85".
# PyMOL>set dash_gap, 0.5, line85
#  Setting: dash_gap set to 0.50000 in object "line85".
# PyMOL>pseudoatom int_AY_2, pos=[392.948, 255.253, 280.930], color=blue
#  ObjMol: created int_AY_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line86, com_AY, int_AY_2
#  Executive: object "line86" created.
# PyMOL>set dash_width, 4, line86
#  Setting: dash_width set to 4.00000 in object "line86".
# PyMOL>set dash_gap, 0.5, line86
#  Setting: dash_gap set to 0.50000 in object "line86".
# PyMOL>pseudoatom int_AY_3, pos=[387.724, 257.036, 249.960], color=blue
#  ObjMol: created int_AY_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line87, com_AY, int_AY_3
#  Executive: object "line87" created.
# PyMOL>set dash_width, 4, line87
#  Setting: dash_width set to 4.00000 in object "line87".
# PyMOL>set dash_gap, 0.5, line87
#  Setting: dash_gap set to 0.50000 in object "line87".
# PyMOL>pseudoatom int_AY_4, pos=[398.117, 267.078, 266.386], color=blue
#  ObjMol: created int_AY_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line88, com_AY, int_AY_4
#  Executive: object "line88" created.
# PyMOL>set dash_width, 4, line88
#  Setting: dash_width set to 4.00000 in object "line88".
# PyMOL>set dash_gap, 0.5, line88
#  Setting: dash_gap set to 0.50000 in object "line88".
# PyMOL>pseudoatom com_AZ, pos=[347.462, 229.080, 364.301], color=red
#  ObjMol: created com_AZ/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_AZ_1, pos=[347.943, 252.448, 363.995], color=blue
#  ObjMol: created int_AZ_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line89, com_AZ, int_AZ_1
#  Executive: object "line89" created.
# PyMOL>set dash_width, 4, line89
#  Setting: dash_width set to 4.00000 in object "line89".
# PyMOL>set dash_gap, 0.5, line89
#  Setting: dash_gap set to 0.50000 in object "line89".
# PyMOL>pseudoatom int_AZ_2, pos=[353.776, 224.447, 350.897], color=blue
#  ObjMol: created int_AZ_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line90, com_AZ, int_AZ_2
#  Executive: object "line90" created.
# PyMOL>set dash_width, 4, line90
#  Setting: dash_width set to 4.00000 in object "line90".
# PyMOL>set dash_gap, 0.5, line90
#  Setting: dash_gap set to 0.50000 in object "line90".
# PyMOL>pseudoatom int_AZ_3, pos=[346.609, 228.911, 368.709], color=blue
#  ObjMol: created int_AZ_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line91, com_AZ, int_AZ_3
#  Executive: object "line91" created.
# PyMOL>set dash_width, 4, line91
#  Setting: dash_width set to 4.00000 in object "line91".
# PyMOL>set dash_gap, 0.5, line91
#  Setting: dash_gap set to 0.50000 in object "line91".
# PyMOL>pseudoatom int_AZ_4, pos=[353.776, 224.447, 350.897], color=blue
#  ObjMol: created int_AZ_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line92, com_AZ, int_AZ_4
#  Executive: object "line92" created.
# PyMOL>set dash_width, 4, line92
#  Setting: dash_width set to 4.00000 in object "line92".
# PyMOL>set dash_gap, 0.5, line92
#  Setting: dash_gap set to 0.50000 in object "line92".
# PyMOL>pseudoatom com_BA, pos=[366.613, 265.472, 355.360], color=red
#  ObjMol: created com_BA/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BA_1, pos=[357.012, 255.358, 362.181], color=blue
#  ObjMol: created int_BA_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line93, com_BA, int_BA_1
#  Executive: object "line93" created.
# PyMOL>set dash_width, 4, line93
#  Setting: dash_width set to 4.00000 in object "line93".
# PyMOL>set dash_gap, 0.5, line93
#  Setting: dash_gap set to 0.50000 in object "line93".
# PyMOL>pseudoatom int_BA_2, pos=[369.862, 257.685, 333.561], color=blue
#  ObjMol: created int_BA_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line94, com_BA, int_BA_2
#  Executive: object "line94" created.
# PyMOL>set dash_width, 4, line94
#  Setting: dash_width set to 4.00000 in object "line94".
# PyMOL>set dash_gap, 0.5, line94
#  Setting: dash_gap set to 0.50000 in object "line94".
# PyMOL>pseudoatom int_BA_3, pos=[369.375, 268.397, 354.542], color=blue
#  ObjMol: created int_BA_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line95, com_BA, int_BA_3
#  Executive: object "line95" created.
# PyMOL>set dash_width, 4, line95
#  Setting: dash_width set to 4.00000 in object "line95".
# PyMOL>set dash_gap, 0.5, line95
#  Setting: dash_gap set to 0.50000 in object "line95".
# PyMOL>pseudoatom com_BB, pos=[373.047, 232.036, 332.346], color=red
#  ObjMol: created com_BB/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BB_1, pos=[353.339, 222.857, 340.932], color=blue
#  ObjMol: created int_BB_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line96, com_BB, int_BB_1
#  Executive: object "line96" created.
# PyMOL>set dash_width, 4, line96
#  Setting: dash_width set to 4.00000 in object "line96".
# PyMOL>set dash_gap, 0.5, line96
#  Setting: dash_gap set to 0.50000 in object "line96".
# PyMOL>pseudoatom int_BB_2, pos=[372.260, 247.297, 335.078], color=blue
#  ObjMol: created int_BB_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line97, com_BB, int_BB_2
#  Executive: object "line97" created.
# PyMOL>set dash_width, 4, line97
#  Setting: dash_width set to 4.00000 in object "line97".
# PyMOL>set dash_gap, 0.5, line97
#  Setting: dash_gap set to 0.50000 in object "line97".
# PyMOL>pseudoatom int_BB_3, pos=[353.339, 222.857, 340.932], color=blue
#  ObjMol: created int_BB_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line98, com_BB, int_BB_3
#  Executive: object "line98" created.
# PyMOL>set dash_width, 4, line98
#  Setting: dash_width set to 4.00000 in object "line98".
# PyMOL>set dash_gap, 0.5, line98
#  Setting: dash_gap set to 0.50000 in object "line98".
# PyMOL>pseudoatom int_BB_4, pos=[372.875, 228.028, 332.551], color=blue
#  ObjMol: created int_BB_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line99, com_BB, int_BB_4
#  Executive: object "line99" created.
# PyMOL>set dash_width, 4, line99
#  Setting: dash_width set to 4.00000 in object "line99".
# PyMOL>set dash_gap, 0.5, line99
#  Setting: dash_gap set to 0.50000 in object "line99".
# PyMOL>pseudoatom com_BC, pos=[369.080, 194.102, 225.615], color=red
#  ObjMol: created com_BC/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BC_1, pos=[376.537, 206.182, 244.185], color=blue
#  ObjMol: created int_BC_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line100, com_BC, int_BC_1
#  Executive: object "line100" created.
# PyMOL>set dash_width, 4, line100
#  Setting: dash_width set to 4.00000 in object "line100".
# PyMOL>set dash_gap, 0.5, line100
#  Setting: dash_gap set to 0.50000 in object "line100".
# PyMOL>pseudoatom int_BC_2, pos=[366.054, 204.580, 214.568], color=blue
#  ObjMol: created int_BC_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line101, com_BC, int_BC_2
#  Executive: object "line101" created.
# PyMOL>set dash_width, 4, line101
#  Setting: dash_width set to 4.00000 in object "line101".
# PyMOL>set dash_gap, 0.5, line101
#  Setting: dash_gap set to 0.50000 in object "line101".
# PyMOL>pseudoatom int_BC_3, pos=[370.541, 190.188, 227.267], color=blue
#  ObjMol: created int_BC_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line102, com_BC, int_BC_3
#  Executive: object "line102" created.
# PyMOL>set dash_width, 4, line102
#  Setting: dash_width set to 4.00000 in object "line102".
# PyMOL>set dash_gap, 0.5, line102
#  Setting: dash_gap set to 0.50000 in object "line102".
# PyMOL>pseudoatom int_BC_4, pos=[366.054, 204.580, 214.568], color=blue
#  ObjMol: created int_BC_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line103, com_BC, int_BC_4
#  Executive: object "line103" created.
# PyMOL>set dash_width, 4, line103
#  Setting: dash_width set to 4.00000 in object "line103".
# PyMOL>set dash_gap, 0.5, line103
#  Setting: dash_gap set to 0.50000 in object "line103".
# PyMOL>pseudoatom com_BD, pos=[391.349, 225.449, 242.718], color=red
#  ObjMol: created com_BD/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BD_1, pos=[394.080, 228.425, 243.449], color=blue
#  ObjMol: created int_BD_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line104, com_BD, int_BD_1
#  Executive: object "line104" created.
# PyMOL>set dash_width, 4, line104
#  Setting: dash_width set to 4.00000 in object "line104".
# PyMOL>set dash_gap, 0.5, line104
#  Setting: dash_gap set to 0.50000 in object "line104".
# PyMOL>pseudoatom int_BD_2, pos=[383.855, 211.913, 241.449], color=blue
#  ObjMol: created int_BD_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line105, com_BD, int_BD_2
#  Executive: object "line105" created.
# PyMOL>set dash_width, 4, line105
#  Setting: dash_width set to 4.00000 in object "line105".
# PyMOL>set dash_gap, 0.5, line105
#  Setting: dash_gap set to 0.50000 in object "line105".
# PyMOL>pseudoatom int_BD_3, pos=[380.682, 240.199, 228.053], color=blue
#  ObjMol: created int_BD_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line106, com_BD, int_BD_3
#  Executive: object "line106" created.
# PyMOL>set dash_width, 4, line106
#  Setting: dash_width set to 4.00000 in object "line106".
# PyMOL>set dash_gap, 0.5, line106
#  Setting: dash_gap set to 0.50000 in object "line106".
# PyMOL>pseudoatom com_BE, pos=[374.709, 229.340, 205.342], color=red
#  ObjMol: created com_BE/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BE_1, pos=[359.943, 211.967, 210.492], color=blue
#  ObjMol: created int_BE_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line107, com_BE, int_BE_1
#  Executive: object "line107" created.
# PyMOL>set dash_width, 4, line107
#  Setting: dash_width set to 4.00000 in object "line107".
# PyMOL>set dash_gap, 0.5, line107
#  Setting: dash_gap set to 0.50000 in object "line107".
# PyMOL>pseudoatom int_BE_2, pos=[380.143, 234.565, 218.912], color=blue
#  ObjMol: created int_BE_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line108, com_BE, int_BE_2
#  Executive: object "line108" created.
# PyMOL>set dash_width, 4, line108
#  Setting: dash_width set to 4.00000 in object "line108".
# PyMOL>set dash_gap, 0.5, line108
#  Setting: dash_gap set to 0.50000 in object "line108".
# PyMOL>pseudoatom int_BE_3, pos=[359.943, 211.967, 210.492], color=blue
#  ObjMol: created int_BE_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line109, com_BE, int_BE_3
#  Executive: object "line109" created.
# PyMOL>set dash_width, 4, line109
#  Setting: dash_width set to 4.00000 in object "line109".
# PyMOL>set dash_gap, 0.5, line109
#  Setting: dash_gap set to 0.50000 in object "line109".
# PyMOL>pseudoatom int_BE_4, pos=[373.422, 227.107, 202.261], color=blue
#  ObjMol: created int_BE_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line110, com_BE, int_BE_4
#  Executive: object "line110" created.
# PyMOL>set dash_width, 4, line110
#  Setting: dash_width set to 4.00000 in object "line110".
# PyMOL>set dash_gap, 0.5, line110
#  Setting: dash_gap set to 0.50000 in object "line110".
# PyMOL>pseudoatom com_BF, pos=[306.417, 240.508, 389.669], color=red
#  ObjMol: created com_BF/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BF_1, pos=[325.468, 247.186, 377.886], color=blue
#  ObjMol: created int_BF_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line111, com_BF, int_BF_1
#  Executive: object "line111" created.
# PyMOL>set dash_width, 4, line111
#  Setting: dash_width set to 4.00000 in object "line111".
# PyMOL>set dash_gap, 0.5, line111
#  Setting: dash_gap set to 0.50000 in object "line111".
# PyMOL>pseudoatom int_BF_2, pos=[301.684, 227.266, 383.092], color=blue
#  ObjMol: created int_BF_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line112, com_BF, int_BF_2
#  Executive: object "line112" created.
# PyMOL>set dash_width, 4, line112
#  Setting: dash_width set to 4.00000 in object "line112".
# PyMOL>set dash_gap, 0.5, line112
#  Setting: dash_gap set to 0.50000 in object "line112".
# PyMOL>pseudoatom int_BF_3, pos=[307.216, 243.349, 393.055], color=blue
#  ObjMol: created int_BF_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line113, com_BF, int_BF_3
#  Executive: object "line113" created.
# PyMOL>set dash_width, 4, line113
#  Setting: dash_width set to 4.00000 in object "line113".
# PyMOL>set dash_gap, 0.5, line113
#  Setting: dash_gap set to 0.50000 in object "line113".
# PyMOL>pseudoatom int_BF_4, pos=[301.684, 227.266, 383.092], color=blue
#  ObjMol: created int_BF_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line114, com_BF, int_BF_4
#  Executive: object "line114" created.
# PyMOL>set dash_width, 4, line114
#  Setting: dash_width set to 4.00000 in object "line114".
# PyMOL>set dash_gap, 0.5, line114
#  Setting: dash_gap set to 0.50000 in object "line114".
# PyMOL>pseudoatom com_BG, pos=[342.671, 231.790, 370.157], color=red
#  ObjMol: created com_BG/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BG_1, pos=[346.161, 230.045, 368.881], color=blue
#  ObjMol: created int_BG_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line115, com_BG, int_BG_1
#  Executive: object "line115" created.
# PyMOL>set dash_width, 4, line115
#  Setting: dash_width set to 4.00000 in object "line115".
# PyMOL>set dash_gap, 0.5, line115
#  Setting: dash_gap set to 0.50000 in object "line115".
# PyMOL>pseudoatom int_BG_2, pos=[331.815, 239.849, 377.785], color=blue
#  ObjMol: created int_BG_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line116, com_BG, int_BG_2
#  Executive: object "line116" created.
# PyMOL>set dash_width, 4, line116
#  Setting: dash_width set to 4.00000 in object "line116".
# PyMOL>set dash_gap, 0.5, line116
#  Setting: dash_gap set to 0.50000 in object "line116".
# PyMOL>pseudoatom int_BG_3, pos=[331.221, 215.910, 357.384], color=blue
#  ObjMol: created int_BG_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line117, com_BG, int_BG_3
#  Executive: object "line117" created.
# PyMOL>set dash_width, 4, line117
#  Setting: dash_width set to 4.00000 in object "line117".
# PyMOL>set dash_gap, 0.5, line117
#  Setting: dash_gap set to 0.50000 in object "line117".
# PyMOL>pseudoatom com_BH, pos=[311.724, 204.747, 370.239], color=red
#  ObjMol: created com_BH/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_BH_1, pos=[296.985, 222.164, 375.320], color=blue
#  ObjMol: created int_BH_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line118, com_BH, int_BH_1
#  Executive: object "line118" created.
# PyMOL>set dash_width, 4, line118
#  Setting: dash_width set to 4.00000 in object "line118".
# PyMOL>set dash_gap, 0.5, line118
#  Setting: dash_gap set to 0.50000 in object "line118".
# PyMOL>pseudoatom int_BH_2, pos=[324.520, 211.435, 364.536], color=blue
#  ObjMol: created int_BH_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line119, com_BH, int_BH_2
#  Executive: object "line119" created.
# PyMOL>set dash_width, 4, line119
#  Setting: dash_width set to 4.00000 in object "line119".
# PyMOL>set dash_gap, 0.5, line119
#  Setting: dash_gap set to 0.50000 in object "line119".
# PyMOL>pseudoatom int_BH_3, pos=[296.985, 222.164, 375.320], color=blue
#  ObjMol: created int_BH_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line120, com_BH, int_BH_3
#  Executive: object "line120" created.
# PyMOL>set dash_width, 4, line120
# ...
#  Executive: object "line623" created.
# PyMOL>set dash_width, 4, line623
#  Setting: dash_width set to 4.00000 in object "line623".
# PyMOL>set dash_gap, 0.5, line623
#  Setting: dash_gap set to 0.50000 in object "line623".
# PyMOL>pseudoatom com_GP, pos=[139.065, 265.303, 263.530], color=red
#  ObjMol: created com_GP/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GP_1, pos=[148.203, 257.009, 283.382], color=blue
#  ObjMol: created int_GP_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line624, com_GP, int_GP_1
#  Executive: object "line624" created.
# PyMOL>set dash_width, 4, line624
#  Setting: dash_width set to 4.00000 in object "line624".
# PyMOL>set dash_gap, 0.5, line624
#  Setting: dash_gap set to 0.50000 in object "line624".
# PyMOL>pseudoatom int_GP_2, pos=[137.874, 267.077, 266.932], color=blue
#  ObjMol: created int_GP_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line625, com_GP, int_GP_2
#  Executive: object "line625" created.
# PyMOL>set dash_width, 4, line625
#  Setting: dash_width set to 4.00000 in object "line625".
# PyMOL>set dash_gap, 0.5, line625
#  Setting: dash_gap set to 0.50000 in object "line625".
# PyMOL>pseudoatom int_GP_3, pos=[148.203, 257.009, 283.382], color=blue
#  ObjMol: created int_GP_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line626, com_GP, int_GP_3
#  Executive: object "line626" created.
# PyMOL>set dash_width, 4, line626
#  Setting: dash_width set to 4.00000 in object "line626".
# PyMOL>set dash_gap, 0.5, line626
#  Setting: dash_gap set to 0.50000 in object "line626".
# PyMOL>pseudoatom int_GP_4, pos=[143.073, 255.257, 252.394], color=blue
#  ObjMol: created int_GP_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line627, com_GP, int_GP_4
#  Executive: object "line627" created.
# PyMOL>set dash_width, 4, line627
#  Setting: dash_width set to 4.00000 in object "line627".
# PyMOL>set dash_gap, 0.5, line627
#  Setting: dash_gap set to 0.50000 in object "line627".
# PyMOL>pseudoatom com_GQ, pos=[166.920, 194.102, 307.705], color=red
#  ObjMol: created com_GQ/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GQ_1, pos=[169.946, 204.580, 318.752], color=blue
#  ObjMol: created int_GQ_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line628, com_GQ, int_GQ_1
#  Executive: object "line628" created.
# PyMOL>set dash_width, 4, line628
#  Setting: dash_width set to 4.00000 in object "line628".
# PyMOL>set dash_gap, 0.5, line628
#  Setting: dash_gap set to 0.50000 in object "line628".
# PyMOL>pseudoatom int_GQ_2, pos=[165.459, 190.188, 306.053], color=blue
#  ObjMol: created int_GQ_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line629, com_GQ, int_GQ_2
#  Executive: object "line629" created.
# PyMOL>set dash_width, 4, line629
#  Setting: dash_width set to 4.00000 in object "line629".
# PyMOL>set dash_gap, 0.5, line629
#  Setting: dash_gap set to 0.50000 in object "line629".
# PyMOL>pseudoatom int_GQ_3, pos=[159.463, 206.182, 289.135], color=blue
#  ObjMol: created int_GQ_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line630, com_GQ, int_GQ_3
#  Executive: object "line630" created.
# PyMOL>set dash_width, 4, line630
#  Setting: dash_width set to 4.00000 in object "line630".
# PyMOL>set dash_gap, 0.5, line630
#  Setting: dash_gap set to 0.50000 in object "line630".
# PyMOL>pseudoatom int_GQ_4, pos=[169.946, 204.580, 318.752], color=blue
#  ObjMol: created int_GQ_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line631, com_GQ, int_GQ_4
#  Executive: object "line631" created.
# PyMOL>set dash_width, 4, line631
#  Setting: dash_width set to 4.00000 in object "line631".
# PyMOL>set dash_gap, 0.5, line631
#  Setting: dash_gap set to 0.50000 in object "line631".
# PyMOL>pseudoatom com_GR, pos=[144.652, 225.449, 290.602], color=red
#  ObjMol: created com_GR/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GR_1, pos=[141.925, 228.430, 289.875], color=blue
#  ObjMol: created int_GR_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line632, com_GR, int_GR_1
#  Executive: object "line632" created.
# PyMOL>set dash_width, 4, line632
#  Setting: dash_width set to 4.00000 in object "line632".
# PyMOL>set dash_gap, 0.5, line632
#  Setting: dash_gap set to 0.50000 in object "line632".
# PyMOL>pseudoatom int_GR_2, pos=[152.123, 211.899, 291.861], color=blue
#  ObjMol: created int_GR_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line633, com_GR, int_GR_2
#  Executive: object "line633" created.
# PyMOL>set dash_width, 4, line633
#  Setting: dash_width set to 4.00000 in object "line633".
# PyMOL>set dash_gap, 0.5, line633
#  Setting: dash_gap set to 0.50000 in object "line633".
# PyMOL>pseudoatom int_GR_3, pos=[155.382, 240.188, 305.231], color=blue
#  ObjMol: created int_GR_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line634, com_GR, int_GR_3
#  Executive: object "line634" created.
# PyMOL>set dash_width, 4, line634
#  Setting: dash_width set to 4.00000 in object "line634".
# PyMOL>set dash_gap, 0.5, line634
#  Setting: dash_gap set to 0.50000 in object "line634".
# PyMOL>pseudoatom com_GS, pos=[161.292, 229.340, 327.978], color=red
#  ObjMol: created com_GS/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GS_1, pos=[176.103, 212.011, 322.813], color=blue
#  ObjMol: created int_GS_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line635, com_GS, int_GS_1
#  Executive: object "line635" created.
# PyMOL>set dash_width, 4, line635
#  Setting: dash_width set to 4.00000 in object "line635".
# PyMOL>set dash_gap, 0.5, line635
#  Setting: dash_gap set to 0.50000 in object "line635".
# PyMOL>pseudoatom int_GS_2, pos=[162.585, 227.109, 331.057], color=blue
#  ObjMol: created int_GS_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line636, com_GS, int_GS_2
#  Executive: object "line636" created.
# PyMOL>set dash_width, 4, line636
#  Setting: dash_width set to 4.00000 in object "line636".
# PyMOL>set dash_gap, 0.5, line636
#  Setting: dash_gap set to 0.50000 in object "line636".
# PyMOL>pseudoatom int_GS_3, pos=[176.103, 212.011, 322.813], color=blue
#  ObjMol: created int_GS_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line637, com_GS, int_GS_3
#  Executive: object "line637" created.
# PyMOL>set dash_width, 4, line637
#  Setting: dash_width set to 4.00000 in object "line637".
# PyMOL>set dash_gap, 0.5, line637
#  Setting: dash_gap set to 0.50000 in object "line637".
# PyMOL>pseudoatom int_GS_4, pos=[155.841, 234.560, 314.412], color=blue
#  ObjMol: created int_GS_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line638, com_GS, int_GS_4
#  Executive: object "line638" created.
# PyMOL>set dash_width, 4, line638
#  Setting: dash_width set to 4.00000 in object "line638".
# PyMOL>set dash_gap, 0.5, line638
#  Setting: dash_gap set to 0.50000 in object "line638".
# PyMOL>pseudoatom com_GT, pos=[183.912, 369.391, 263.222], color=red
#  ObjMol: created com_GT/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GT_1, pos=[195.121, 372.154, 252.843], color=blue
#  ObjMol: created int_GT_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line639, com_GT, int_GT_1
#  Executive: object "line639" created.
# PyMOL>set dash_width, 4, line639
#  Setting: dash_width set to 4.00000 in object "line639".
# PyMOL>set dash_gap, 0.5, line639
#  Setting: dash_gap set to 0.50000 in object "line639".
# PyMOL>pseudoatom int_GT_2, pos=[180.694, 370.463, 266.168], color=blue
#  ObjMol: created int_GT_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line640, com_GT, int_GT_2
#  Executive: object "line640" created.
# PyMOL>set dash_width, 4, line640
#  Setting: dash_width set to 4.00000 in object "line640".
# PyMOL>set dash_gap, 0.5, line640
#  Setting: dash_gap set to 0.50000 in object "line640".
# PyMOL>pseudoatom int_GT_3, pos=[172.327, 350.632, 255.458], color=blue
#  ObjMol: created int_GT_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line641, com_GT, int_GT_3
#  Executive: object "line641" created.
# PyMOL>set dash_width, 4, line641
#  Setting: dash_width set to 4.00000 in object "line641".
# PyMOL>set dash_gap, 0.5, line641
#  Setting: dash_gap set to 0.50000 in object "line641".
# PyMOL>pseudoatom int_GT_4, pos=[195.121, 372.154, 252.843], color=blue
#  ObjMol: created int_GT_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line642, com_GT, int_GT_4
#  Executive: object "line642" created.
# PyMOL>set dash_width, 4, line642
#  Setting: dash_width set to 4.00000 in object "line642".
# PyMOL>set dash_gap, 0.5, line642
#  Setting: dash_gap set to 0.50000 in object "line642".
# PyMOL>pseudoatom com_GU, pos=[167.031, 346.762, 232.012], color=red
#  ObjMol: created com_GU/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GU_1, pos=[165.377, 345.524, 228.464], color=blue
#  ObjMol: created int_GU_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line643, com_GU, int_GU_1
#  Executive: object "line643" created.
# PyMOL>set dash_width, 4, line643
#  Setting: dash_width set to 4.00000 in object "line643".
# PyMOL>set dash_gap, 0.5, line643
#  Setting: dash_gap set to 0.50000 in object "line643".
# PyMOL>pseudoatom int_GU_2, pos=[169.537, 352.251, 246.315], color=blue
#  ObjMol: created int_GU_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line644, com_GU, int_GU_2
#  Executive: object "line644" created.
# PyMOL>set dash_width, 4, line644
#  Setting: dash_width set to 4.00000 in object "line644".
# PyMOL>set dash_gap, 0.5, line644
#  Setting: dash_gap set to 0.50000 in object "line644".
# PyMOL>pseudoatom int_GU_3, pos=[187.556, 347.950, 220.891], color=blue
#  ObjMol: created int_GU_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line645, com_GU, int_GU_3
#  Executive: object "line645" created.
# PyMOL>set dash_width, 4, line645
#  Setting: dash_width set to 4.00000 in object "line645".
# PyMOL>set dash_gap, 0.5, line645
#  Setting: dash_gap set to 0.50000 in object "line645".
# PyMOL>pseudoatom com_GV, pos=[200.383, 369.912, 225.634], color=red
#  ObjMol: created com_GV/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GV_1, pos=[204.377, 369.882, 248.665], color=blue
#  ObjMol: created int_GV_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line646, com_GV, int_GV_1
#  Executive: object "line646" created.
# PyMOL>set dash_width, 4, line646
#  Setting: dash_width set to 4.00000 in object "line646".
# PyMOL>set dash_gap, 0.5, line646
#  Setting: dash_gap set to 0.50000 in object "line646".
# PyMOL>pseudoatom int_GV_2, pos=[202.274, 373.125, 227.130], color=blue
#  ObjMol: created int_GV_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line647, com_GV, int_GV_2
#  Executive: object "line647" created.
# PyMOL>set dash_width, 4, line647
#  Setting: dash_width set to 4.00000 in object "line647".
# PyMOL>set dash_gap, 0.5, line647
#  Setting: dash_gap set to 0.50000 in object "line647".
# PyMOL>pseudoatom int_GV_3, pos=[204.377, 369.882, 248.665], color=blue
#  ObjMol: created int_GV_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line648, com_GV, int_GV_3
#  Executive: object "line648" created.
# PyMOL>set dash_width, 4, line648
#  Setting: dash_width set to 4.00000 in object "line648".
# PyMOL>set dash_gap, 0.5, line648
#  Setting: dash_gap set to 0.50000 in object "line648".
# PyMOL>pseudoatom int_GV_4, pos=[190.819, 357.997, 222.886], color=blue
#  ObjMol: created int_GV_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line649, com_GV, int_GV_4
#  Executive: object "line649" created.
# PyMOL>set dash_width, 4, line649
#  Setting: dash_width set to 4.00000 in object "line649".
# PyMOL>set dash_gap, 0.5, line649
#  Setting: dash_gap set to 0.50000 in object "line649".
# PyMOL>pseudoatom com_GW, pos=[229.583, 240.508, 143.651], color=red
#  ObjMol: created com_GW/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GW_1, pos=[234.316, 227.266, 150.228], color=blue
#  ObjMol: created int_GW_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line650, com_GW, int_GW_1
#  Executive: object "line650" created.
# PyMOL>set dash_width, 4, line650
#  Setting: dash_width set to 4.00000 in object "line650".
# PyMOL>set dash_gap, 0.5, line650
#  Setting: dash_gap set to 0.50000 in object "line650".
# PyMOL>pseudoatom int_GW_2, pos=[228.784, 243.349, 140.265], color=blue
#  ObjMol: created int_GW_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line651, com_GW, int_GW_2
#  Executive: object "line651" created.
# PyMOL>set dash_width, 4, line651
#  Setting: dash_width set to 4.00000 in object "line651".
# PyMOL>set dash_gap, 0.5, line651
#  Setting: dash_gap set to 0.50000 in object "line651".
# PyMOL>pseudoatom int_GW_3, pos=[210.532, 247.186, 155.434], color=blue
#  ObjMol: created int_GW_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line652, com_GW, int_GW_3
#  Executive: object "line652" created.
# PyMOL>set dash_width, 4, line652
#  Setting: dash_width set to 4.00000 in object "line652".
# PyMOL>set dash_gap, 0.5, line652
#  Setting: dash_gap set to 0.50000 in object "line652".
# PyMOL>pseudoatom int_GW_4, pos=[234.316, 227.266, 150.228], color=blue
#  ObjMol: created int_GW_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line653, com_GW, int_GW_4
#  Executive: object "line653" created.
# PyMOL>set dash_width, 4, line653
#  Setting: dash_width set to 4.00000 in object "line653".
# PyMOL>set dash_gap, 0.5, line653
#  Setting: dash_gap set to 0.50000 in object "line653".
# PyMOL>pseudoatom com_GX, pos=[193.329, 231.790, 163.163], color=red
#  ObjMol: created com_GX/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GX_1, pos=[189.839, 230.045, 164.437], color=blue
#  ObjMol: created int_GX_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line654, com_GX, int_GX_1
#  Executive: object "line654" created.
# PyMOL>set dash_width, 4, line654
#  Setting: dash_width set to 4.00000 in object "line654".
# PyMOL>set dash_gap, 0.5, line654
#  Setting: dash_gap set to 0.50000 in object "line654".
# PyMOL>pseudoatom int_GX_2, pos=[204.187, 239.852, 155.540], color=blue
#  ObjMol: created int_GX_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line655, com_GX, int_GX_2
#  Executive: object "line655" created.
# PyMOL>set dash_width, 4, line655
#  Setting: dash_width set to 4.00000 in object "line655".
# PyMOL>set dash_gap, 0.5, line655
#  Setting: dash_gap set to 0.50000 in object "line655".
# PyMOL>pseudoatom int_GX_3, pos=[204.775, 215.906, 175.934], color=blue
#  ObjMol: created int_GX_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line656, com_GX, int_GX_3
#  Executive: object "line656" created.
# PyMOL>set dash_width, 4, line656
#  Setting: dash_width set to 4.00000 in object "line656".
# PyMOL>set dash_gap, 0.5, line656
#  Setting: dash_gap set to 0.50000 in object "line656".
# PyMOL>pseudoatom com_GY, pos=[224.277, 204.747, 163.081], color=red
#  ObjMol: created com_GY/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_GY_1, pos=[239.014, 222.161, 157.985], color=blue
#  ObjMol: created int_GY_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line657, com_GY, int_GY_1
#  Executive: object "line657" created.
# PyMOL>set dash_width, 4, line657
#  Setting: dash_width set to 4.00000 in object "line657".
# PyMOL>set dash_gap, 0.5, line657
#  Setting: dash_gap set to 0.50000 in object "line657".
# PyMOL>pseudoatom int_GY_2, pos=[227.547, 203.768, 160.964], color=blue
#  ObjMol: created int_GY_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line658, com_GY, int_GY_2
#  Executive: object "line658" created.
# PyMOL>set dash_width, 4, line658
#  Setting: dash_width set to 4.00000 in object "line658".
# PyMOL>set dash_gap, 0.5, line658
#  Setting: dash_gap set to 0.50000 in object "line658".
# PyMOL>pseudoatom int_GY_3, pos=[239.014, 222.161, 157.985], color=blue
#  ObjMol: created int_GY_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line659, com_GY, int_GY_3
#  Executive: object "line659" created.
# PyMOL>set dash_width, 4, line659
#  Setting: dash_width set to 4.00000 in object "line659".
# PyMOL>set dash_gap, 0.5, line659
#  Setting: dash_gap set to 0.50000 in object "line659".
# PyMOL>pseudoatom int_GY_4, pos=[211.483, 211.438, 168.787], color=blue
#  ObjMol: created int_GY_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line660, com_GY, int_GY_4
#  Executive: object "line660" created.
# PyMOL>set dash_width, 4, line660
#  Setting: dash_width set to 4.00000 in object "line660".
# PyMOL>set dash_gap, 0.5, line660
#  Setting: dash_gap set to 0.50000 in object "line660".
# PyMOL>set sphere_transparency, 0.2
#  Setting: sphere_transparency set to 0.20000.
# PyMOL>bg_color white
# PyMOL>zoom all
# PyMOL>load /Users/sikao/Documents/5lqp_dir/5lqp.cif
# TITLE     Cryo-EM reconstruction of bacteriophage AP205 virus-like particles.
#  ExecutiveLoad-Detail: Detected mmCIF
#  CmdLoad: "/Users/sikao/Documents/5lqp_dir/5lqp.cif" loaded as "5lqp".
# PyMOL>spectrum chain
#  Spectrum: Expression is non-numeric, enumerating values
#  Spectrum: range ( 0.00000 to 180.00000).
# PyMOL>hide everything, 5lqp
# PyMOL>show cartoon, 5lqp
# PyMOL>set cartoon_transparency, 0.7, 5lqp
#  Setting: cartoon_transparency set to 0.70000 in object "5lqp".
# PyMOL>png /Users/sikao/Documents/5lqp_dir/comparison_regularized.png, 800, 800, 150, 1
#  Ray: render time: 35.95 sec. = 100.1 frames/hour (35.95 sec. accum.).
#  ScenePNG: wrote 800x800 pixel image to file "/Users/sikao/Documents/5lqp_dir/comparison_regularized.png".
