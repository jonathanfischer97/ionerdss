# %%
import sys
import os

# Go two levels up from docs/source/ to reach the project root
# sys.path.insert(0, os.path.abspath('../../'))

import ionerdss as ion
import subprocess
from IPython.display import display, Image

# %% [markdown]
# Homo 5mer

# %%
pdb_id = '8f8p'
save_folder = '~/Documents/8f8p_dir'

pdb_model = ion.PDBModel(pdb_id=pdb_id, save_dir=save_folder)

# set standard_output=True to see the determined interfaces
pdb_model.coarse_grain(distance_cutoff=0.35, 
                       residue_cutoff=3,
                       show_coarse_grained_structure=False, 
                       save_pymol_script=False, 
                       standard_output=True)
# Out:
# Successfully downloaded assembly file: /Users/sikao/Documents/8f8p_dir/8f8p-assembly1.cif.gz
# Binding interfaces detected:
# Chain A:
#   Center of Mass (COM): (138.63644409179688, 154.12098693847656, 219.00856018066406)
#   Interfaces: ['B', 'C']
#   Interface Coordinates:
#     (133.75579833984375, 141.09860229492188, 211.27639770507812)
#     Interface Energy: -0.10
#     (143.97813415527344, 154.2287139892578, 196.29736328125)
#     Interface Energy: -9.02
# Chain B:
#   Center of Mass (COM): (134.18763732910156, 123.00177001953125, 191.228515625)
#   Interfaces: ['A', 'C', 'D']
#   Interface Coordinates:
#     (137.8016815185547, 131.69215393066406, 209.1024932861328)
#     Interface Energy: -0.10
#     (142.60450744628906, 135.40200805664062, 186.58624267578125)
#     Interface Energy: 1.77
#     (128.9962921142578, 124.14057159423828, 168.51048278808594)
#     Interface Energy: -10.11
# Chain C:
#   Center of Mass (COM): (145.7298126220703, 152.23406982421875, 163.42855834960938)
#   Interfaces: ['A', 'B', 'D', 'E']
#   Interface Coordinates:
#     (140.66552734375, 153.98179626464844, 191.480712890625)
#     Interface Energy: -9.02
#     (139.62799072265625, 146.91000366210938, 184.08120727539062)
#     Interface Energy: 1.77
#     (134.71400451660156, 142.08074951171875, 158.76800537109375)
#     Interface Energy: 1.77
#     (150.4071807861328, 149.22193908691406, 140.78359985351562)
#     Interface Energy: -9.15
# Chain D:
#   Center of Mass (COM): (127.69400024414062, 126.41368865966797, 135.64610290527344)
#   Interfaces: ['B', 'C', 'E']
#   Interface Coordinates:
#     (133.3052215576172, 122.78935241699219, 163.65786743164062)
#     Interface Energy: -10.11
#     (134.95321655273438, 130.20919799804688, 156.2617950439453)
#     Interface Energy: 1.77
#     (140.75625610351562, 133.7064971923828, 130.91824340820312)
#     Interface Energy: 3.09
# Chain E:
#   Center of Mass (COM): (151.5953826904297, 147.4991912841797, 107.91771697998047)
#   Interfaces: ['C', 'D']
#   Interface Coordinates:
#     (148.5364990234375, 149.15757751464844, 135.19900512695312)
#     Interface Energy: -9.15
#     (142.97076416015625, 143.74024963378906, 127.91600036621094)
#     Interface Energy: 3.09

# %%
pdb_model.regularize_homologous_chains(dist_threshold_intra=3.5, 
                                       dist_threshold_inter=3.5, 
                                       angle_threshold=25.0, 
                                       show_coarse_grained_structure=False, 
                                       save_pymol_script=True, 
                                       standard_output=False)
# Out:
# Homologous chains identified using sequence alignment:
# {'B': 'A', 'D': 'A', 'E': 'A', 'A': 'A', 'C': 'A'}
# Homologous chain groups identified:
# [['A', 'B', 'C', 'D', 'E']]
# Regularized coarse-grained structure saved to /Users/sikao/Documents/8f8p_dir/regularized_coarse_grained_structure.cif.
# PyMOL script saved to /Users/sikao/Documents/8f8p_dir/visualize_regularized_coarse_grained.pml.
# Model saved successfully to /Users/sikao/Documents/8f8p_dir/8f8p_model.json

# %%
if save_folder.startswith('~'):
    abs_save_folder = os.path.expanduser(save_folder)
abs_save_folder = os.path.abspath(abs_save_folder)

subprocess.run(["pymol", "-cq", f"{abs_save_folder}/visualize_regularized_coarse_grained.pml"], check=True)
display(Image(filename=f"{abs_save_folder}/comparison_regularized.png"))
# Out:
# PyMOL>load /Users/sikao/Documents/8f8p_dir/regularized_coarse_grained_structure.cif, coarse_grained
#  ExecutiveLoad-Detail: Detected mmCIF
#  CmdLoad: "/Users/sikao/Documents/8f8p_dir/regularized_coarse_grained_structure.cif" loaded as "coarse_grained".
# PyMOL>hide everything
# PyMOL>show spheres, name COM
# PyMOL>show spheres, name INT
# PyMOL>set sphere_scale, 1.0
#  Setting: sphere_scale set to 1.00000.
# PyMOL>color red, name COM
#  Executive: Colored 5 atoms.
# PyMOL>color blue, name INT
#  Executive: Colored 14 atoms.
# PyMOL>pseudoatom com_A, pos=[138.636, 154.121, 219.009], color=red
#  ObjMol: created com_A/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_A_1, pos=[133.756, 141.099, 211.276], color=blue
#  ObjMol: created int_A_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line1, com_A, int_A_1
#  Executive: object "line1" created.
# PyMOL>set dash_width, 4, line1
#  Setting: dash_width set to 4.00000 in object "line1".
# PyMOL>set dash_gap, 0.5, line1
#  Setting: dash_gap set to 0.50000 in object "line1".
# PyMOL>pseudoatom int_A_2, pos=[143.978, 154.229, 196.297], color=blue
#  ObjMol: created int_A_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line2, com_A, int_A_2
#  Executive: object "line2" created.
# PyMOL>set dash_width, 4, line2
#  Setting: dash_width set to 4.00000 in object "line2".
# PyMOL>set dash_gap, 0.5, line2
#  Setting: dash_gap set to 0.50000 in object "line2".
# PyMOL>pseudoatom com_B, pos=[134.187, 123.002, 191.228], color=red
#  ObjMol: created com_B/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_B_1, pos=[137.801, 131.692, 209.102], color=blue
#  ObjMol: created int_B_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line3, com_B, int_B_1
#  Executive: object "line3" created.
# PyMOL>set dash_width, 4, line3
#  Setting: dash_width set to 4.00000 in object "line3".
# PyMOL>set dash_gap, 0.5, line3
#  Setting: dash_gap set to 0.50000 in object "line3".
# PyMOL>pseudoatom int_B_2, pos=[141.953, 134.549, 183.512], color=blue
#  ObjMol: created int_B_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line4, com_B, int_B_2
#  Executive: object "line4" created.
# PyMOL>set dash_width, 4, line4
#  Setting: dash_width set to 4.00000 in object "line4".
# PyMOL>set dash_gap, 0.5, line4
#  Setting: dash_gap set to 0.50000 in object "line4".
# PyMOL>pseudoatom int_B_3, pos=[128.996, 124.140, 168.511], color=blue
#  ObjMol: created int_B_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line5, com_B, int_B_3
#  Executive: object "line5" created.
# PyMOL>set dash_width, 4, line5
#  Setting: dash_width set to 4.00000 in object "line5".
# PyMOL>set dash_gap, 0.5, line5
#  Setting: dash_gap set to 0.50000 in object "line5".
# PyMOL>pseudoatom com_C, pos=[145.730, 152.234, 163.429], color=red
#  ObjMol: created com_C/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_C_1, pos=[140.666, 153.982, 191.481], color=blue
#  ObjMol: created int_C_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line6, com_C, int_C_1
#  Executive: object "line6" created.
# PyMOL>set dash_width, 4, line6
#  Setting: dash_width set to 4.00000 in object "line6".
# PyMOL>set dash_gap, 0.5, line6
#  Setting: dash_gap set to 0.50000 in object "line6".
# PyMOL>pseudoatom int_C_2, pos=[140.195, 144.602, 181.294], color=blue
#  ObjMol: created int_C_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line7, com_C, int_C_2
#  Executive: object "line7" created.
# PyMOL>set dash_width, 4, line7
#  Setting: dash_width set to 4.00000 in object "line7".
# PyMOL>set dash_gap, 0.5, line7
#  Setting: dash_gap set to 0.50000 in object "line7".
# PyMOL>pseudoatom int_C_3, pos=[135.549, 142.762, 155.695], color=blue
#  ObjMol: created int_C_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line8, com_C, int_C_3
#  Executive: object "line8" created.
# PyMOL>set dash_width, 4, line8
#  Setting: dash_width set to 4.00000 in object "line8".
# PyMOL>set dash_gap, 0.5, line8
#  Setting: dash_gap set to 0.50000 in object "line8".
# PyMOL>pseudoatom int_C_4, pos=[150.567, 149.936, 140.720], color=blue
#  ObjMol: created int_C_4/PSDO/P/PSD`1 /PS1
# PyMOL>distance line9, com_C, int_C_4
#  Executive: object "line9" created.
# PyMOL>set dash_width, 4, line9
#  Setting: dash_width set to 4.00000 in object "line9".
# PyMOL>set dash_gap, 0.5, line9
#  Setting: dash_gap set to 0.50000 in object "line9".
# PyMOL>pseudoatom com_D, pos=[127.694, 126.414, 135.646], color=red
#  ObjMol: created com_D/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_D_1, pos=[132.324, 123.590, 163.686], color=blue
#  ObjMol: created int_D_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line10, com_D, int_D_1
#  Executive: object "line10" created.
# PyMOL>set dash_width, 4, line10
#  Setting: dash_width set to 4.00000 in object "line10".
# PyMOL>set dash_gap, 0.5, line10
#  Setting: dash_gap set to 0.50000 in object "line10".
# PyMOL>pseudoatom int_D_2, pos=[134.929, 132.581, 153.470], color=blue
#  ObjMol: created int_D_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line11, com_D, int_D_2
#  Executive: object "line11" created.
# PyMOL>set dash_width, 4, line11
#  Setting: dash_width set to 4.00000 in object "line11".
# PyMOL>set dash_gap, 0.5, line11
#  Setting: dash_gap set to 0.50000 in object "line11".
# PyMOL>pseudoatom int_D_3, pos=[139.773, 133.233, 127.850], color=blue
#  ObjMol: created int_D_3/PSDO/P/PSD`1 /PS1
# PyMOL>distance line12, com_D, int_D_3
#  Executive: object "line12" created.
# PyMOL>set dash_width, 4, line12
#  Setting: dash_width set to 4.00000 in object "line12".
# PyMOL>set dash_gap, 0.5, line12
#  Setting: dash_gap set to 0.50000 in object "line12".
# PyMOL>pseudoatom com_E, pos=[151.596, 147.499, 107.918], color=red
#  ObjMol: created com_E/PSDO/P/PSD`1 /PS1
# PyMOL>pseudoatom int_E_1, pos=[147.334, 151.253, 135.906], color=blue
#  ObjMol: created int_E_1/PSDO/P/PSD`1 /PS1
# PyMOL>distance line13, com_E, int_E_1
#  Executive: object "line13" created.
# PyMOL>set dash_width, 4, line13
#  Setting: dash_width set to 4.00000 in object "line13".
# PyMOL>set dash_gap, 0.5, line13
#  Setting: dash_gap set to 0.50000 in object "line13".
# PyMOL>pseudoatom int_E_2, pos=[142.875, 143.128, 125.607], color=blue
#  ObjMol: created int_E_2/PSDO/P/PSD`1 /PS1
# PyMOL>distance line14, com_E, int_E_2
#  Executive: object "line14" created.
# PyMOL>set dash_width, 4, line14
#  Setting: dash_width set to 4.00000 in object "line14".
# PyMOL>set dash_gap, 0.5, line14
#  Setting: dash_gap set to 0.50000 in object "line14".
# PyMOL>set sphere_transparency, 0.2
#  Setting: sphere_transparency set to 0.20000.
# PyMOL>bg_color white
# PyMOL>zoom all
# PyMOL>load /Users/sikao/Documents/8f8p_dir/8f8p.cif
# TITLE     Cryo-EM structure of F-actin in the ADP state
#  ExecutiveLoad-Detail: Detected mmCIF
#  CmdLoad: "/Users/sikao/Documents/8f8p_dir/8f8p.cif" loaded as "8f8p".
# PyMOL>spectrum chain
#  Spectrum: Expression is non-numeric, enumerating values
#  Spectrum: range ( 0.00000 to  5.00000).
# PyMOL>hide everything, 8f8p
# PyMOL>show cartoon, 8f8p
# PyMOL>set cartoon_transparency, 0.7, 8f8p
#  Setting: cartoon_transparency set to 0.70000 in object "8f8p".
# PyMOL>png /Users/sikao/Documents/8f8p_dir/comparison_regularized.png, 800, 800, 150, 1
#  Ray: render time: 2.27 sec. = 1585.9 frames/hour (2.27 sec. accum.).
#  ScenePNG: wrote 800x800 pixel image to file "/Users/sikao/Documents/8f8p_dir/comparison_regularized.png".
